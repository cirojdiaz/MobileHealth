# %%
#import libraries
import pandas as pd
import numpy as np
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.calibration import CalibratedClassifierCV
from sklearn.naive_bayes import CategoricalNB
from sklearn.multioutput import ClassifierChain
from sklearn.naive_bayes import ComplementNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.dummy import DummyClassifier
from sklearn.tree import ExtraTreeClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.semi_supervised import LabelPropagation
from sklearn.semi_supervised import LabelSpreading
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LogisticRegressionCV
from sklearn.neural_network import MLPClassifier
from sklearn.multioutput import MultiOutputClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import NearestCentroid
from sklearn.svm import NuSVC
from sklearn.multiclass import OneVsOneClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.multiclass import OutputCodeClassifier
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.linear_model import Perceptron
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.neighbors import RadiusNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import RidgeClassifier
from sklearn.linear_model import RidgeClassifierCV
from sklearn.linear_model import SGDClassifier
from sklearn.svm import SVC
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import accuracy_score,classification_report
import sklearn.impute as imputers
from sklearn.model_selection import StratifiedKFold
import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.utils import all_estimators
estimators = all_estimators(type_filter='classifier')
classification_estimators = []
i = 1
for name, class_ in estimators:
    classification_estimators.append(class_.__name__)
print(len(classification_estimators))
# Out:
# 41

# %%
#load data
df = pd.read_csv('var_of_interest.csv')
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values
df.head()
df["PostCond"].value_counts()
# Out:
# 1    62257
# 0    21063
# Name: PostCond, dtype: int64

# %%
# #Splitting the dataset into the Training set and Test set
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
skf = StratifiedKFold(n_splits = 10, shuffle=True, random_state=42)

indices = skf.split(X, y)
X_train = dict()
y_train = dict()
X_test = dict()
y_test = dict()
cnt = 0
from sklearn.preprocessing import StandardScaler

from imblearn.combine import SMOTEENN
from imblearn.under_sampling import EditedNearestNeighbours
from imblearn.over_sampling import SMOTE

for train_i, test_i in indices:
    X_train_i = X[train_i]
    X_test_i = X[test_i]
    y_train_i = y[train_i]
    y_test_i = y[test_i]

    sc1 = StandardScaler()
    imputer = imputers.IterativeImputer(random_state=42)
    resampler = SMOTE()
    
    X_train_i = imputer.fit_transform(X_train_i)
    X_train_i = sc1.fit_transform(X_train_i)
    print(f'train len before resample: {len(X_train_i)}')
    X_train_i, y_train_i = resampler.fit_resample(X_train_i, y_train_i)
    print(f'train len after resample: {len(X_train_i)}')
    print(f'Num of positive train: {np.sum(y_train_i)}')
    print(f'Num of negative train: {len(y_train_i) - np.sum(y_train_i)}')

    X_test_i = imputer.transform(X_test_i)
    X_test_i = sc1.transform(X_test_i)
    
    X_train[cnt] = X_train_i
    X_test[cnt] = X_test_i
    y_train[cnt] = y_train_i
    y_test[cnt] = y_test_i

    cnt += 1
# Out:
# train len before resample: 74988
# train len after resample: 112062
# Num of positive train: 56031
# Num of negative train: 56031
# train len before resample: 74988
# train len after resample: 112062
# Num of positive train: 56031
# Num of negative train: 56031
# train len before resample: 74988
# train len after resample: 112062
# Num of positive train: 56031
# Num of negative train: 56031
# train len before resample: 74988
# train len after resample: 112062
# Num of positive train: 56031
# Num of negative train: 56031
# train len before resample: 74988
# train len after resample: 112062
# Num of positive train: 56031
# Num of negative train: 56031
# train len before resample: 74988
# train len after resample: 112062
# Num of positive train: 56031
# Num of negative train: 56031
# train len before resample: 74988
# train len after resample: 112062
# Num of positive train: 56031
# Num of negative train: 56031
# train len before resample: 74988
# train len after resample: 112064
# Num of positive train: 56032
# Num of negative train: 56032
# train len before resample: 74988
# train len after resample: 112064
# Num of positive train: 56032
# Num of negative train: 56032
# train len before resample: 74988
# train len after resample: 112064
# Num of positive train: 56032
# Num of negative train: 56032

# %%
# #Scaling the Dataset
# from sklearn.preprocessing import StandardScaler
# sc1 = StandardScaler()
# sc2 = StandardScaler()
# imputer = imputers.IterativeImputer(random_state=42)
# # X_train = sc1.fit_transform(X_train)
# X_train = imputer.fit_transform(X_train)
# X_train = sc2.fit_transform(X_train)
# # X_test = sc1.transform(X_test)
# X_test = imputer.transform(X_test)
# X_test = sc2.transform(X_test)

# %%
models=[AdaBoostClassifier,BaggingClassifier,BernoulliNB,CalibratedClassifierCV,DecisionTreeClassifier,DummyClassifier,
        ExtraTreeClassifier,ExtraTreesClassifier,GaussianNB,GradientBoostingClassifier,HistGradientBoostingClassifier,KNeighborsClassifier,
        LinearDiscriminantAnalysis,LinearSVC,LogisticRegression,LogisticRegressionCV,MLPClassifier,
        NearestCentroid,PassiveAggressiveClassifier,Perceptron,QuadraticDiscriminantAnalysis,
        RandomForestClassifier,RidgeClassifier,RidgeClassifierCV,SGDClassifier,SVC] 

cross_val_models = dict()
for i in range(10):
        cross_val_models[i] = list()
        for model in models:
                cross_val_models[i].append(model)
            
#CategoricalNB
#ClassifierChain
#ComplementNB
#GaussianProcessClassifier
#LabelPropagation
#LabelSpreading
#MultinomialNB
#NuSVC
#OneVsOneClassifier
#OneVsRestClassifier,
#OutputCodeClassifier
#RadiusNeighborsClassifier
#StackingClassifier
#VotingClassifier

# %%
#Fitting the Model
from statistics import mean
from sklearn.metrics import balanced_accuracy_score, recall_score, precision_score, f1_score, accuracy_score
model_accuracies =[]
model_balanced_accuracies = []
model_recalls = []
model_precisions = []
model_f1 = []

for i in range(len(models)):
    accuracies = list()
    balanced_accuracies = list()
    recalls = list()
    precisions = list()
    f1 = list()
    for k in X_train.keys():
        model = cross_val_models[k][i]()
        model.fit(X_train[k], y_train[k])
        y_pred= model.predict(X_test[k])
        accuracies.append(round(accuracy_score(y_test[k], y_pred),4))
        balanced_accuracies.append(round(balanced_accuracy_score(y_test[k], y_pred),4))
        recalls.append(round(recall_score(y_test[k], y_pred), 4))
        precisions.append(round(precision_score(y_test[k], y_pred), 4))
        f1.append(round(f1_score(y_test[k], y_pred), 4))

    model_accuracies.append(mean(accuracies))
    model_balanced_accuracies.append(mean(balanced_accuracies))
    model_recalls.append(mean(recalls))
    model_precisions.append(mean(precisions))
    model_f1.append(mean(f1))

    print (f'model : {models[i]} and  accuracy score is : {mean(accuracies)}, balanced accuracy score: {mean(balanced_accuracies)}, recall: {mean(recalls)}, precision: {mean(precisions)}, f1: {mean(f1)}')
    
result_df1 = pd.DataFrame({'Accuracy':model_accuracies, 'Balanced Accuracy': model_balanced_accuracies, 'Recall':model_recalls, 'Precision':model_precisions, 'f1':model_f1}, index=models)
result_df1
# Out:
# model : <class 'sklearn.ensemble._weight_boosting.AdaBoostClassifier'> and  accuracy score is : 0.61351, balanced accuracy score: 0.56046, recall: 0.66773, precision: 0.78311, f1: 0.72077
# model : <class 'sklearn.ensemble._bagging.BaggingClassifier'> and  accuracy score is : 0.67779, balanced accuracy score: 0.5692200000000001, recall: 0.78888, precision: 0.78189, f1: 0.78536
# model : <class 'sklearn.naive_bayes.BernoulliNB'> and  accuracy score is : 0.53962, balanced accuracy score: 0.55246, recall: 0.52652, precision: 0.78683, f1: 0.63084
# model : <class 'sklearn.calibration.CalibratedClassifierCV'> and  accuracy score is : 0.32082, balanced accuracy score: 0.4633, recall: 0.17506, precision: 0.67551, f1: 0.27804
# model : <class 'sklearn.tree._classes.DecisionTreeClassifier'> and  accuracy score is : 0.63871, balanced accuracy score: 0.55342, recall: 0.7259599999999999, precision: 0.77605, f1: 0.75017
# model : <class 'sklearn.dummy.DummyClassifier'> and  accuracy score is : 0.25283, balanced accuracy score: 0.5, recall: 0.0, precision: 0.0, f1: 0.0
# model : <class 'sklearn.tree._classes.ExtraTreeClassifier'> and  accuracy score is : 0.61838, balanced accuracy score: 0.5545599999999999, recall: 0.68362, precision: 0.77861, f1: 0.72801
# model : <class 'sklearn.ensemble._forest.ExtraTreesClassifier'> and  accuracy score is : 0.74917, balanced accuracy score: 0.60043, recall: 0.90123, precision: 0.79183, f1: 0.84302
# model : <class 'sklearn.naive_bayes.GaussianNB'> and  accuracy score is : 0.30452, balanced accuracy score: 0.5003, recall: 0.10434, precision: 0.74676, f1: 0.18287
# model : <class 'sklearn.ensemble._gb.GradientBoostingClassifier'> and  accuracy score is : 0.71251, balanced accuracy score: 0.5119400000000001, recall: 0.9176, precision: 0.75218, f1: 0.8266399999999999
# model : <class 'sklearn.ensemble._hist_gradient_boosting.gradient_boosting.HistGradientBoostingClassifier'> and  accuracy score is : 0.72799, balanced accuracy score: 0.51849, recall: 0.94226, precision: 0.75467, f1: 0.8381
# model : <class 'sklearn.neighbors._classification.KNeighborsClassifier'> and  accuracy score is : 0.57856, balanced accuracy score: 0.56905, recall: 0.58828, precision: 0.79437, f1: 0.67593
# model : <class 'sklearn.discriminant_analysis.LinearDiscriminantAnalysis'> and  accuracy score is : 0.55455, balanced accuracy score: 0.55323, recall: 0.5559, precision: 0.78518, f1: 0.65093
# model : <class 'sklearn.svm._classes.LinearSVC'> and  accuracy score is : 0.55336, balanced accuracy score: 0.5536, recall: 0.55314, precision: 0.78569, f1: 0.6492
# model : <class 'sklearn.linear_model._logistic.LogisticRegression'> and  accuracy score is : 0.55378, balanced accuracy score: 0.55458, recall: 0.55294, precision: 0.78644, f1: 0.64932
# model : <class 'sklearn.linear_model._logistic.LogisticRegressionCV'> and  accuracy score is : 0.55377, balanced accuracy score: 0.55456, recall: 0.55299, precision: 0.7864, f1: 0.64933
# model : <class 'sklearn.neural_network._multilayer_perceptron.MLPClassifier'> and  accuracy score is : 0.59354, balanced accuracy score: 0.57079, recall: 0.61678, precision: 0.7936, f1: 0.69347
# model : <class 'sklearn.neighbors._nearest_centroid.NearestCentroid'> and  accuracy score is : 0.54999, balanced accuracy score: 0.54813, recall: 0.55194, precision: 0.78166, f1: 0.64699
# model : <class 'sklearn.linear_model._passive_aggressive.PassiveAggressiveClassifier'> and  accuracy score is : 0.5024, balanced accuracy score: 0.50819, recall: 0.49649, precision: 0.75239, f1: 0.5953
# model : <class 'sklearn.linear_model._perceptron.Perceptron'> and  accuracy score is : 0.50314, balanced accuracy score: 0.51311, recall: 0.49295, precision: 0.75799, f1: 0.59234
# model : <class 'sklearn.discriminant_analysis.QuadraticDiscriminantAnalysis'> and  accuracy score is : 0.31899, balanced accuracy score: 0.49626, recall: 0.13769, precision: 0.73645, f1: 0.23175
# model : <class 'sklearn.ensemble._forest.RandomForestClassifier'> and  accuracy score is : 0.74044, balanced accuracy score: 0.57138, recall: 0.91333, precision: 0.77796, f1: 0.84022
# model : <class 'sklearn.linear_model._ridge.RidgeClassifier'> and  accuracy score is : 0.55455, balanced accuracy score: 0.55323, recall: 0.5559, precision: 0.78518, f1: 0.65093
# model : <class 'sklearn.linear_model._ridge.RidgeClassifierCV'> and  accuracy score is : 0.5545599999999999, balanced accuracy score: 0.55324, recall: 0.55592, precision: 0.7851899999999999, f1: 0.65094
# model : <class 'sklearn.linear_model._stochastic_gradient.SGDClassifier'> and  accuracy score is : 0.54415, balanced accuracy score: 0.54162, recall: 0.5467299999999999, precision: 0.77735, f1: 0.63981
# model : <class 'sklearn.svm._classes.SVC'> and  accuracy score is : 0.58162, balanced accuracy score: 0.5803, recall: 0.58295, precision: 0.80316, f1: 0.67552
#                                                     Accuracy  \
# <class 'sklearn.ensemble._weight_boosting.AdaBo...   0.61351
# <class 'sklearn.ensemble._bagging.BaggingClassi...   0.67779
# <class 'sklearn.naive_bayes.BernoulliNB'>            0.53962
# <class 'sklearn.calibration.CalibratedClassifie...   0.32082
# <class 'sklearn.tree._classes.DecisionTreeClass...   0.63871
# <class 'sklearn.dummy.DummyClassifier'>              0.25283
# <class 'sklearn.tree._classes.ExtraTreeClassifi...   0.61838
# <class 'sklearn.ensemble._forest.ExtraTreesClas...   0.74917
# <class 'sklearn.naive_bayes.GaussianNB'>             0.30452
# <class 'sklearn.ensemble._gb.GradientBoostingCl...   0.71251
# <class 'sklearn.ensemble._hist_gradient_boostin...   0.72799
# <class 'sklearn.neighbors._classification.KNeig...   0.57856
# <class 'sklearn.discriminant_analysis.LinearDis...   0.55455
# <class 'sklearn.svm._classes.LinearSVC'>             0.55336
# <class 'sklearn.linear_model._logistic.Logistic...   0.55378
# <class 'sklearn.linear_model._logistic.Logistic...   0.55377
# <class 'sklearn.neural_network._multilayer_perc...   0.59354
# <class 'sklearn.neighbors._nearest_centroid.Nea...   0.54999
# <class 'sklearn.linear_model._passive_aggressiv...   0.50240
# <class 'sklearn.linear_model._perceptron.Percep...   0.50314
# <class 'sklearn.discriminant_analysis.Quadratic...   0.31899
# <class 'sklearn.ensemble._forest.RandomForestCl...   0.74044
# <class 'sklearn.linear_model._ridge.RidgeClassi...   0.55455
# <class 'sklearn.linear_model._ridge.RidgeClassi...   0.55456
# <class 'sklearn.linear_model._stochastic_gradie...   0.54415
# <class 'sklearn.svm._classes.SVC'>                   0.58162
#
#                                                     Balanced Accuracy  \
# <class 'sklearn.ensemble._weight_boosting.AdaBo...            0.56046
# <class 'sklearn.ensemble._bagging.BaggingClassi...            0.56922
# <class 'sklearn.naive_bayes.BernoulliNB'>                     0.55246
# <class 'sklearn.calibration.CalibratedClassifie...            0.46330
# <class 'sklearn.tree._classes.DecisionTreeClass...            0.55342
# <class 'sklearn.dummy.DummyClassifier'>                       0.50000
# <class 'sklearn.tree._classes.ExtraTreeClassifi...            0.55456
# <class 'sklearn.ensemble._forest.ExtraTreesClas...            0.60043
# <class 'sklearn.naive_bayes.GaussianNB'>                      0.50030
# <class 'sklearn.ensemble._gb.GradientBoostingCl...            0.51194
# <class 'sklearn.ensemble._hist_gradient_boostin...            0.51849
# <class 'sklearn.neighbors._classification.KNeig...            0.56905
# <class 'sklearn.discriminant_analysis.LinearDis...            0.55323
# <class 'sklearn.svm._classes.LinearSVC'>                      0.55360
# <class 'sklearn.linear_model._logistic.Logistic...            0.55458
# <class 'sklearn.linear_model._logistic.Logistic...            0.55456
# <class 'sklearn.neural_network._multilayer_perc...            0.57079
# <class 'sklearn.neighbors._nearest_centroid.Nea...            0.54813
# <class 'sklearn.linear_model._passive_aggressiv...            0.50819
# <class 'sklearn.linear_model._perceptron.Percep...            0.51311
# <class 'sklearn.discriminant_analysis.Quadratic...            0.49626
# <class 'sklearn.ensemble._forest.RandomForestCl...            0.57138
# <class 'sklearn.linear_model._ridge.RidgeClassi...            0.55323
# <class 'sklearn.linear_model._ridge.RidgeClassi...            0.55324
# <class 'sklearn.linear_model._stochastic_gradie...            0.54162
# <class 'sklearn.svm._classes.SVC'>                            0.58030
#
#                                                      Recall  Precision  \
# <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.66773    0.78311
# <class 'sklearn.ensemble._bagging.BaggingClassi...  0.78888    0.78189
# <class 'sklearn.naive_bayes.BernoulliNB'>           0.52652    0.78683
# <class 'sklearn.calibration.CalibratedClassifie...  0.17506    0.67551
# <class 'sklearn.tree._classes.DecisionTreeClass...  0.72596    0.77605
# <class 'sklearn.dummy.DummyClassifier'>             0.00000    0.00000
# <class 'sklearn.tree._classes.ExtraTreeClassifi...  0.68362    0.77861
# <class 'sklearn.ensemble._forest.ExtraTreesClas...  0.90123    0.79183
# <class 'sklearn.naive_bayes.GaussianNB'>            0.10434    0.74676
# <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.91760    0.75218
# <class 'sklearn.ensemble._hist_gradient_boostin...  0.94226    0.75467
# <class 'sklearn.neighbors._classification.KNeig...  0.58828    0.79437
# <class 'sklearn.discriminant_analysis.LinearDis...  0.55590    0.78518
# <class 'sklearn.svm._classes.LinearSVC'>            0.55314    0.78569
# <class 'sklearn.linear_model._logistic.Logistic...  0.55294    0.78644
# <class 'sklearn.linear_model._logistic.Logistic...  0.55299    0.78640
# <class 'sklearn.neural_network._multilayer_perc...  0.61678    0.79360
# <class 'sklearn.neighbors._nearest_centroid.Nea...  0.55194    0.78166
# <class 'sklearn.linear_model._passive_aggressiv...  0.49649    0.75239
# <class 'sklearn.linear_model._perceptron.Percep...  0.49295    0.75799
# <class 'sklearn.discriminant_analysis.Quadratic...  0.13769    0.73645
# <class 'sklearn.ensemble._forest.RandomForestCl...  0.91333    0.77796
# <class 'sklearn.linear_model._ridge.RidgeClassi...  0.55590    0.78518
# <class 'sklearn.linear_model._ridge.RidgeClassi...  0.55592    0.78519
# <class 'sklearn.linear_model._stochastic_gradie...  0.54673    0.77735
# <class 'sklearn.svm._classes.SVC'>                  0.58295    0.80316
#
#                                                          f1
# <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.72077
# <class 'sklearn.ensemble._bagging.BaggingClassi...  0.78536
# <class 'sklearn.naive_bayes.BernoulliNB'>           0.63084
# <class 'sklearn.calibration.CalibratedClassifie...  0.27804
# <class 'sklearn.tree._classes.DecisionTreeClass...  0.75017
# <class 'sklearn.dummy.DummyClassifier'>             0.00000
# <class 'sklearn.tree._classes.ExtraTreeClassifi...  0.72801
# <class 'sklearn.ensemble._forest.ExtraTreesClas...  0.84302
# <class 'sklearn.naive_bayes.GaussianNB'>            0.18287
# <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.82664
# <class 'sklearn.ensemble._hist_gradient_boostin...  0.83810
# <class 'sklearn.neighbors._classification.KNeig...  0.67593
# <class 'sklearn.discriminant_analysis.LinearDis...  0.65093
# <class 'sklearn.svm._classes.LinearSVC'>            0.64920
# <class 'sklearn.linear_model._logistic.Logistic...  0.64932
# <class 'sklearn.linear_model._logistic.Logistic...  0.64933
# <class 'sklearn.neural_network._multilayer_perc...  0.69347
# <class 'sklearn.neighbors._nearest_centroid.Nea...  0.64699
# <class 'sklearn.linear_model._passive_aggressiv...  0.59530
# <class 'sklearn.linear_model._perceptron.Percep...  0.59234
# <class 'sklearn.discriminant_analysis.Quadratic...  0.23175
# <class 'sklearn.ensemble._forest.RandomForestCl...  0.84022
# <class 'sklearn.linear_model._ridge.RidgeClassi...  0.65093
# <class 'sklearn.linear_model._ridge.RidgeClassi...  0.65094
# <class 'sklearn.linear_model._stochastic_gradie...  0.63981
# <class 'sklearn.svm._classes.SVC'>                  0.67552
