# %%
#import libraries
import pandas as pd
import numpy as np
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.calibration import CalibratedClassifierCV
from sklearn.naive_bayes import CategoricalNB
from sklearn.multioutput import ClassifierChain
from sklearn.naive_bayes import ComplementNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.dummy import DummyClassifier
from sklearn.tree import ExtraTreeClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.semi_supervised import LabelPropagation
from sklearn.semi_supervised import LabelSpreading
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LogisticRegressionCV
from sklearn.neural_network import MLPClassifier
from sklearn.multioutput import MultiOutputClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import NearestCentroid
from sklearn.svm import NuSVC
from sklearn.multiclass import OneVsOneClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.multiclass import OutputCodeClassifier
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.linear_model import Perceptron
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.neighbors import RadiusNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import RidgeClassifier
from sklearn.linear_model import RidgeClassifierCV
from sklearn.linear_model import SGDClassifier
from sklearn.svm import SVC
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import accuracy_score,classification_report
import sklearn.impute as imputers
from sklearn.model_selection import StratifiedKFold
import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.utils import all_estimators
estimators = all_estimators(type_filter='classifier')
classification_estimators = []
i = 1
for name, class_ in estimators:
    classification_estimators.append(class_.__name__)
print(len(classification_estimators))
# Out:
# 41

# %%
#load data
df = pd.read_csv('var_of_interest.csv')
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values
df.head()
df["PostCond"].value_counts()
# Out:
# 1    62257
# 0    21063
# Name: PostCond, dtype: int64

# %%
# #Splitting the dataset into the Training set and Test set
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
skf = StratifiedKFold(n_splits = 10, shuffle=True, random_state=42)

indices = skf.split(X, y)
X_train = dict()
y_train = dict()
X_test = dict()
y_test = dict()
cnt = 0
from sklearn.preprocessing import StandardScaler

from imblearn.combine import SMOTEENN
from imblearn.under_sampling import EditedNearestNeighbours

for train_i, test_i in indices:
    X_train_i = X[train_i]
    X_test_i = X[test_i]
    y_train_i = y[train_i]
    y_test_i = y[test_i]

    sc1 = StandardScaler()
    imputer = imputers.IterativeImputer(random_state=42)
    resampler = SMOTEENN(enn=EditedNearestNeighbours(sampling_strategy='all'))
    
    X_train_i = imputer.fit_transform(X_train_i)
    X_train_i = sc1.fit_transform(X_train_i)
    print(f'train len before resample: {len(X_train_i)}')
    X_train_i, y_train_i = resampler.fit_resample(X_train_i, y_train_i)
    print(f'train len after resample: {len(X_train_i)}')

    X_test_i = imputer.transform(X_test_i)
    X_test_i = sc1.transform(X_test_i)
    
    X_train[cnt] = X_train_i
    X_test[cnt] = X_test_i
    y_train[cnt] = y_train_i
    y_test[cnt] = y_test_i

    cnt += 1
# Out:
# train len before resample: 74988
# train len after resample: 65580
# train len before resample: 74988
# train len after resample: 65050
# train len before resample: 74988
# train len after resample: 65553
# train len before resample: 74988
# train len after resample: 65324
# train len before resample: 74988
# train len after resample: 65509
# train len before resample: 74988
# train len after resample: 65405
# train len before resample: 74988
# train len after resample: 65240
# train len before resample: 74988
# train len after resample: 65404
# train len before resample: 74988
# train len after resample: 65378
# train len before resample: 74988
# train len after resample: 65497

# %%
# #Scaling the Dataset
# from sklearn.preprocessing import StandardScaler
# sc1 = StandardScaler()
# sc2 = StandardScaler()
# imputer = imputers.IterativeImputer(random_state=42)
# # X_train = sc1.fit_transform(X_train)
# X_train = imputer.fit_transform(X_train)
# X_train = sc2.fit_transform(X_train)
# # X_test = sc1.transform(X_test)
# X_test = imputer.transform(X_test)
# X_test = sc2.transform(X_test)

# %%
models=[AdaBoostClassifier,BaggingClassifier,BernoulliNB,CalibratedClassifierCV,DecisionTreeClassifier,DummyClassifier,
        ExtraTreeClassifier,ExtraTreesClassifier,GaussianNB,GradientBoostingClassifier,HistGradientBoostingClassifier,KNeighborsClassifier,
        LinearDiscriminantAnalysis,LinearSVC,LogisticRegression,LogisticRegressionCV,MLPClassifier,
        NearestCentroid,PassiveAggressiveClassifier,Perceptron,QuadraticDiscriminantAnalysis,
        RandomForestClassifier,RidgeClassifier,RidgeClassifierCV,SGDClassifier,SVC] 

cross_val_models = dict()
for i in range(10):
        cross_val_models[i] = list()
        for model in models:
                cross_val_models[i].append(model)
            
#CategoricalNB
#ClassifierChain
#ComplementNB
#GaussianProcessClassifier
#LabelPropagation
#LabelSpreading
#MultinomialNB
#NuSVC
#OneVsOneClassifier
#OneVsRestClassifier,
#OutputCodeClassifier
#RadiusNeighborsClassifier
#StackingClassifier
#VotingClassifier

# %%
#Fitting the Model
from statistics import mean
from sklearn.metrics import balanced_accuracy_score, recall_score, precision_score, f1_score
model_accuracies =[]
model_recalls = []
model_precisions = []
model_f1 = []

for i in range(len(models)):
    accuracies = list()
    recalls = list()
    precisions = list()
    f1 = list()
    for k in X_train.keys():
        model = cross_val_models[k][i]()
        model.fit(X_train[k], y_train[k])
        y_pred= model.predict(X_test[k])
        accuracies.append(round(balanced_accuracy_score(y_test[k], y_pred),4))
        recalls.append(round(recall_score(y_test[k], y_pred), 4))
        precisions.append(round(precision_score(y_test[k], y_pred), 4))
        f1.append(round(f1_score(y_test[k], y_pred), 4))

    model_accuracies.append(mean(accuracies))
    model_recalls.append(mean(recalls))
    model_precisions.append(mean(precisions))
    model_f1.append(mean(f1))

    print (f'model : {models[i]} and  accuracy score is : {mean(accuracies)}, recall: {mean(recalls)}, precision: {mean(precisions)}, f1: {mean(f1)}')
    
result_df1 = pd.DataFrame({'Accuracy':model_accuracies, 'Recall':model_recalls, 'Precision':model_precisions, 'f1':model_f1}, index=models)
result_df1
# Out:
# model : <class 'sklearn.ensemble._weight_boosting.AdaBoostClassifier'> and  accuracy score is : 0.56745, recall: 0.30541, precision: 0.84119, f1: 0.44801
# model : <class 'sklearn.ensemble._bagging.BaggingClassifier'> and  accuracy score is : 0.58219, recall: 0.55334, precision: 0.80789, f1: 0.6567999999999999
# model : <class 'sklearn.naive_bayes.BernoulliNB'> and  accuracy score is : 0.53155, recall: 0.15865, precision: 0.83054, f1: 0.26632
# model : <class 'sklearn.calibration.CalibratedClassifierCV'> and  accuracy score is : 0.50001, recall: 2e-05, precision: 0.1, f1: 2.9999999999999997e-05
# model : <class 'sklearn.tree._classes.DecisionTreeClassifier'> and  accuracy score is : 0.54905, recall: 0.60567, precision: 0.77908, f1: 0.68153
# model : <class 'sklearn.dummy.DummyClassifier'> and  accuracy score is : 0.5, recall: 0.0, precision: 0.0, f1: 0.0
# model : <class 'sklearn.tree._classes.ExtraTreeClassifier'> and  accuracy score is : 0.55105, recall: 0.5397, precision: 0.78478, f1: 0.6395
# model : <class 'sklearn.ensemble._forest.ExtraTreesClassifier'> and  accuracy score is : 0.60349, recall: 0.57313, precision: 0.82228, f1: 0.6754600000000001
# model : <class 'sklearn.naive_bayes.GaussianNB'> and  accuracy score is : 0.50502, recall: 0.040690000000000004, precision: 0.79903, f1: 0.07726
# model : <class 'sklearn.ensemble._gb.GradientBoostingClassifier'> and  accuracy score is : 0.5915900000000001, recall: 0.42545, precision: 0.83858, f1: 0.56438
# model : <class 'sklearn.ensemble._hist_gradient_boosting.gradient_boosting.HistGradientBoostingClassifier'> and  accuracy score is : 0.59562, recall: 0.61378, precision: 0.81109, f1: 0.69874
# model : <class 'sklearn.neighbors._classification.KNeighborsClassifier'> and  accuracy score is : 0.55523, recall: 0.39186, precision: 0.80455, f1: 0.52699
# model : <class 'sklearn.discriminant_analysis.LinearDiscriminantAnalysis'> and  accuracy score is : 0.51237, recall: 0.06939000000000001, precision: 0.82113, f1: 0.12792
# model : <class 'sklearn.svm._classes.LinearSVC'> and  accuracy score is : 0.51007, recall: 0.05987, precision: 0.81691, f1: 0.11149
# model : <class 'sklearn.linear_model._logistic.LogisticRegression'> and  accuracy score is : 0.51338, recall: 0.07479, precision: 0.82143, f1: 0.13704
# model : <class 'sklearn.linear_model._logistic.LogisticRegressionCV'> and  accuracy score is : 0.50118, recall: 0.00897, precision: 0.80082, f1: 0.01777
# model : <class 'sklearn.neural_network._multilayer_perceptron.MLPClassifier'> and  accuracy score is : 0.5601700000000001, recall: 0.38355, precision: 0.8116300000000001, f1: 0.52054
# model : <class 'sklearn.neighbors._nearest_centroid.NearestCentroid'> and  accuracy score is : 0.5456, recall: 0.52793, precision: 0.7813, f1: 0.6300600000000001
# model : <class 'sklearn.linear_model._passive_aggressive.PassiveAggressiveClassifier'> and  accuracy score is : 0.51367, recall: 0.42666000000000004, precision: 0.76118, f1: 0.53948
# model : <class 'sklearn.linear_model._perceptron.Perceptron'> and  accuracy score is : 0.51554, recall: 0.36841, precision: 0.76335, f1: 0.48853
# model : <class 'sklearn.discriminant_analysis.QuadraticDiscriminantAnalysis'> and  accuracy score is : 0.50114, recall: 0.09265, precision: 0.752, f1: 0.16486
# model : <class 'sklearn.ensemble._forest.RandomForestClassifier'> and  accuracy score is : 0.60887, recall: 0.5617, precision: 0.82836, f1: 0.66943
# model : <class 'sklearn.linear_model._ridge.RidgeClassifier'> and  accuracy score is : 0.50919, recall: 0.05524, precision: 0.81593, f1: 0.10342
# model : <class 'sklearn.linear_model._ridge.RidgeClassifierCV'> and  accuracy score is : 0.5092099999999999, recall: 0.055189999999999996, precision: 0.81621, f1: 0.10334
# model : <class 'sklearn.linear_model._stochastic_gradient.SGDClassifier'> and  accuracy score is : 0.50142, recall: 0.00962, precision: 0.82034, f1: 0.01889
# model : <class 'sklearn.svm._classes.SVC'> and  accuracy score is : 0.55102, recall: 0.25255, precision: 0.83219, f1: 0.38742
#                                                     Accuracy   Recall  \
# <class 'sklearn.ensemble._weight_boosting.AdaBo...   0.56745  0.30541
# <class 'sklearn.ensemble._bagging.BaggingClassi...   0.58219  0.55334
# <class 'sklearn.naive_bayes.BernoulliNB'>            0.53155  0.15865
# <class 'sklearn.calibration.CalibratedClassifie...   0.50001  0.00002
# <class 'sklearn.tree._classes.DecisionTreeClass...   0.54905  0.60567
# <class 'sklearn.dummy.DummyClassifier'>              0.50000  0.00000
# <class 'sklearn.tree._classes.ExtraTreeClassifi...   0.55105  0.53970
# <class 'sklearn.ensemble._forest.ExtraTreesClas...   0.60349  0.57313
# <class 'sklearn.naive_bayes.GaussianNB'>             0.50502  0.04069
# <class 'sklearn.ensemble._gb.GradientBoostingCl...   0.59159  0.42545
# <class 'sklearn.ensemble._hist_gradient_boostin...   0.59562  0.61378
# <class 'sklearn.neighbors._classification.KNeig...   0.55523  0.39186
# <class 'sklearn.discriminant_analysis.LinearDis...   0.51237  0.06939
# <class 'sklearn.svm._classes.LinearSVC'>             0.51007  0.05987
# <class 'sklearn.linear_model._logistic.Logistic...   0.51338  0.07479
# <class 'sklearn.linear_model._logistic.Logistic...   0.50118  0.00897
# <class 'sklearn.neural_network._multilayer_perc...   0.56017  0.38355
# <class 'sklearn.neighbors._nearest_centroid.Nea...   0.54560  0.52793
# <class 'sklearn.linear_model._passive_aggressiv...   0.51367  0.42666
# <class 'sklearn.linear_model._perceptron.Percep...   0.51554  0.36841
# <class 'sklearn.discriminant_analysis.Quadratic...   0.50114  0.09265
# <class 'sklearn.ensemble._forest.RandomForestCl...   0.60887  0.56170
# <class 'sklearn.linear_model._ridge.RidgeClassi...   0.50919  0.05524
# <class 'sklearn.linear_model._ridge.RidgeClassi...   0.50921  0.05519
# <class 'sklearn.linear_model._stochastic_gradie...   0.50142  0.00962
# <class 'sklearn.svm._classes.SVC'>                   0.55102  0.25255
#
#                                                     Precision       f1
# <class 'sklearn.ensemble._weight_boosting.AdaBo...    0.84119  0.44801
# <class 'sklearn.ensemble._bagging.BaggingClassi...    0.80789  0.65680
# <class 'sklearn.naive_bayes.BernoulliNB'>             0.83054  0.26632
# <class 'sklearn.calibration.CalibratedClassifie...    0.10000  0.00003
# <class 'sklearn.tree._classes.DecisionTreeClass...    0.77908  0.68153
# <class 'sklearn.dummy.DummyClassifier'>               0.00000  0.00000
# <class 'sklearn.tree._classes.ExtraTreeClassifi...    0.78478  0.63950
# <class 'sklearn.ensemble._forest.ExtraTreesClas...    0.82228  0.67546
# <class 'sklearn.naive_bayes.GaussianNB'>              0.79903  0.07726
# <class 'sklearn.ensemble._gb.GradientBoostingCl...    0.83858  0.56438
# <class 'sklearn.ensemble._hist_gradient_boostin...    0.81109  0.69874
# <class 'sklearn.neighbors._classification.KNeig...    0.80455  0.52699
# <class 'sklearn.discriminant_analysis.LinearDis...    0.82113  0.12792
# <class 'sklearn.svm._classes.LinearSVC'>              0.81691  0.11149
# <class 'sklearn.linear_model._logistic.Logistic...    0.82143  0.13704
# <class 'sklearn.linear_model._logistic.Logistic...    0.80082  0.01777
# <class 'sklearn.neural_network._multilayer_perc...    0.81163  0.52054
# <class 'sklearn.neighbors._nearest_centroid.Nea...    0.78130  0.63006
# <class 'sklearn.linear_model._passive_aggressiv...    0.76118  0.53948
# <class 'sklearn.linear_model._perceptron.Percep...    0.76335  0.48853
# <class 'sklearn.discriminant_analysis.Quadratic...    0.75200  0.16486
# <class 'sklearn.ensemble._forest.RandomForestCl...    0.82836  0.66943
# <class 'sklearn.linear_model._ridge.RidgeClassi...    0.81593  0.10342
# <class 'sklearn.linear_model._ridge.RidgeClassi...    0.81621  0.10334
# <class 'sklearn.linear_model._stochastic_gradie...    0.82034  0.01889
# <class 'sklearn.svm._classes.SVC'>                    0.83219  0.38742
