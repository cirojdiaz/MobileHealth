# %%
#import libraries
import pandas as pd
import numpy as np
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.naive_bayes import BernoulliNB
from sklearn.calibration import CalibratedClassifierCV
from sklearn.naive_bayes import CategoricalNB
from sklearn.multioutput import ClassifierChain
from sklearn.naive_bayes import ComplementNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.dummy import DummyClassifier
from sklearn.tree import ExtraTreeClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import HistGradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.semi_supervised import LabelPropagation
from sklearn.semi_supervised import LabelSpreading
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LogisticRegressionCV
from sklearn.neural_network import MLPClassifier
from sklearn.multioutput import MultiOutputClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import NearestCentroid
from sklearn.svm import NuSVC
from sklearn.multiclass import OneVsOneClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.multiclass import OutputCodeClassifier
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.linear_model import Perceptron
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.neighbors import RadiusNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import RidgeClassifier
from sklearn.linear_model import RidgeClassifierCV
from sklearn.linear_model import SGDClassifier
from sklearn.svm import SVC
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.metrics import accuracy_score,classification_report
import sklearn.impute as imputers
from sklearn.model_selection import StratifiedKFold
import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.utils import all_estimators
estimators = all_estimators(type_filter='classifier')
classification_estimators = []
i = 1
for name, class_ in estimators:
    classification_estimators.append(class_.__name__)
print(len(classification_estimators))
# Out:
# 41

# %%
#load data
df = pd.read_csv('var_of_interest.csv')
X = df.iloc[:, :-1].values
y = df.iloc[:, -1].values
df.head()
df["PostCond"].value_counts()
# Out:
# 1    62257
# 0    21063
# Name: PostCond, dtype: int64

# %%
# #Splitting the dataset into the Training set and Test set
# from sklearn.model_selection import train_test_split
# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.25, random_state = 0)

# %%
skf = StratifiedKFold(n_splits = 10, shuffle=True, random_state=42)

indices = skf.split(X, y)
X_train = dict()
y_train = dict()
X_test = dict()
y_test = dict()
cnt = 0
from sklearn.preprocessing import StandardScaler

from imblearn.combine import SMOTEENN
from imblearn.under_sampling import EditedNearestNeighbours
from imblearn.over_sampling import SMOTE
from dbscan import transform

for train_i, test_i in indices:
    X_train_i = X[train_i]
    X_test_i = X[test_i]
    y_train_i = y[train_i]
    y_test_i = y[test_i]

    sc1 = StandardScaler()
    imputer = imputers.IterativeImputer(random_state=42)
    resampler = SMOTE()
    
    X_train_i = imputer.fit_transform(X_train_i)
    X_train_i = sc1.fit_transform(X_train_i)
    print(f'train len before dbscan: {len(X_train_i)}')
    X_train_i, y_train_i = transform(X_train_i, y_train_i)
    print(f'train len after dbscan: {len(X_train_i)}')
    print(f'train len before resample: {len(X_train_i)}')
    X_train_i, y_train_i = resampler.fit_resample(X_train_i, y_train_i)
    print(f'train len after resample: {len(X_train_i)}')
    print(f'Num of positive train: {np.sum(y_train_i)}')
    print(f'Num of negative train: {len(y_train_i) - np.sum(y_train_i)}')

    X_test_i = imputer.transform(X_test_i)
    X_test_i = sc1.transform(X_test_i)
    
    X_train[cnt] = X_train_i
    X_test[cnt] = X_test_i
    y_train[cnt] = y_train_i
    y_test[cnt] = y_test_i

    cnt += 1
# Out:
# train len before dbscan: 74988
# train len after dbscan: 72164
# train len before resample: 72164
# train len after resample: 107802
# Num of positive train: 53901
# Num of negative train: 53901
# train len before dbscan: 74988
# train len after dbscan: 72091
# train len before resample: 72091
# train len after resample: 107706
# Num of positive train: 53853
# Num of negative train: 53853
# train len before dbscan: 74988
# train len after dbscan: 72155
# train len before resample: 72155
# train len after resample: 107818
# Num of positive train: 53909
# Num of negative train: 53909
# train len before dbscan: 74988
# train len after dbscan: 72163
# train len before resample: 72163
# train len after resample: 107790
# Num of positive train: 53895
# Num of negative train: 53895
# train len before dbscan: 74988
# train len after dbscan: 72131
# train len before resample: 72131
# train len after resample: 107804
# Num of positive train: 53902
# Num of negative train: 53902
# train len before dbscan: 74988
# train len after dbscan: 72207
# train len before resample: 72207
# train len after resample: 107894
# Num of positive train: 53947
# Num of negative train: 53947
# train len before dbscan: 74988
# train len after dbscan: 72105
# train len before resample: 72105
# train len after resample: 107756
# Num of positive train: 53878
# Num of negative train: 53878
# train len before dbscan: 74988
# train len after dbscan: 72179
# train len before resample: 72179
# train len after resample: 107860
# Num of positive train: 53930
# Num of negative train: 53930
# train len before dbscan: 74988
# train len after dbscan: 72139
# train len before resample: 72139
# train len after resample: 107778
# Num of positive train: 53889
# Num of negative train: 53889
# train len before dbscan: 74988
# train len after dbscan: 72082
# train len before resample: 72082
# train len after resample: 107696
# Num of positive train: 53848
# Num of negative train: 53848

# %%
# #Scaling the Dataset
# from sklearn.preprocessing import StandardScaler
# sc1 = StandardScaler()
# sc2 = StandardScaler()
# imputer = imputers.IterativeImputer(random_state=42)
# # X_train = sc1.fit_transform(X_train)
# X_train = imputer.fit_transform(X_train)
# X_train = sc2.fit_transform(X_train)
# # X_test = sc1.transform(X_test)
# X_test = imputer.transform(X_test)
# X_test = sc2.transform(X_test)

# %%
models=[AdaBoostClassifier,BaggingClassifier,BernoulliNB,CalibratedClassifierCV,DecisionTreeClassifier,DummyClassifier,
        ExtraTreeClassifier,ExtraTreesClassifier,GaussianNB,GradientBoostingClassifier,HistGradientBoostingClassifier,KNeighborsClassifier,
        LinearDiscriminantAnalysis,LinearSVC,LogisticRegression,LogisticRegressionCV,MLPClassifier,
        NearestCentroid,PassiveAggressiveClassifier,Perceptron,QuadraticDiscriminantAnalysis,
        RandomForestClassifier,RidgeClassifier,RidgeClassifierCV,SGDClassifier,SVC] 

cross_val_models = dict()
for i in range(10):
        cross_val_models[i] = list()
        for model in models:
                cross_val_models[i].append(model)
            
#CategoricalNB
#ClassifierChain
#ComplementNB
#GaussianProcessClassifier
#LabelPropagation
#LabelSpreading
#MultinomialNB
#NuSVC
#OneVsOneClassifier
#OneVsRestClassifier,
#OutputCodeClassifier
#RadiusNeighborsClassifier
#StackingClassifier
#VotingClassifier

# %%
#Fitting the Model
from statistics import mean
from sklearn.metrics import balanced_accuracy_score, recall_score, precision_score, f1_score, accuracy_score
model_accuracies =[]
model_balanced_accuracies = []
model_recalls = []
model_precisions = []
model_f1 = []

for i in range(len(models)):
    accuracies = list()
    balanced_accuracies = list()
    recalls = list()
    precisions = list()
    f1 = list()
    for k in X_train.keys():
        model = cross_val_models[k][i]()
        model.fit(X_train[k], y_train[k])
        y_pred= model.predict(X_test[k])
        accuracies.append(round(accuracy_score(y_test[k], y_pred),4))
        balanced_accuracies.append(round(balanced_accuracy_score(y_test[k], y_pred),4))
        recalls.append(round(recall_score(y_test[k], y_pred), 4))
        precisions.append(round(precision_score(y_test[k], y_pred), 4))
        f1.append(round(f1_score(y_test[k], y_pred), 4))

    model_accuracies.append(mean(accuracies))
    model_balanced_accuracies.append(mean(balanced_accuracies))
    model_recalls.append(mean(recalls))
    model_precisions.append(mean(precisions))
    model_f1.append(mean(f1))

    print (f'model : {models[i]} and  accuracy score is : {mean(accuracies)}, balanced accuracy score: {mean(balanced_accuracies)}, recall: {mean(recalls)}, precision: {mean(precisions)}, f1: {mean(f1)}')
    
result_df1 = pd.DataFrame({'Accuracy':model_accuracies, 'Balanced Accuracy': model_balanced_accuracies, 'Recall':model_recalls, 'Precision':model_precisions, 'f1':model_f1}, index=models)
result_df1
# Out:
# model : <class 'sklearn.ensemble._weight_boosting.AdaBoostClassifier'> and  accuracy score is : 0.61525, balanced accuracy score: 0.5574600000000001, recall: 0.67433, precision: 0.78091, f1: 0.72364
# model : <class 'sklearn.ensemble._bagging.BaggingClassifier'> and  accuracy score is : 0.67242, balanced accuracy score: 0.56537, recall: 0.7819, precision: 0.78021, f1: 0.78105
# model : <class 'sklearn.naive_bayes.BernoulliNB'> and  accuracy score is : 0.54431, balanced accuracy score: 0.55289, recall: 0.53557, precision: 0.78645, f1: 0.63717
# model : <class 'sklearn.calibration.CalibratedClassifierCV'> and  accuracy score is : 0.32287, balanced accuracy score: 0.45883999999999997, recall: 0.18379, precision: 0.67113, f1: 0.28856
# model : <class 'sklearn.tree._classes.DecisionTreeClassifier'> and  accuracy score is : 0.63425, balanced accuracy score: 0.54976, recall: 0.72066, precision: 0.77423, f1: 0.74646
# model : <class 'sklearn.dummy.DummyClassifier'> and  accuracy score is : 0.25283, balanced accuracy score: 0.5, recall: 0.0, precision: 0.0, f1: 0.0
# model : <class 'sklearn.tree._classes.ExtraTreeClassifier'> and  accuracy score is : 0.61832, balanced accuracy score: 0.5524100000000001, recall: 0.68575, precision: 0.7772, f1: 0.7285699999999999
# model : <class 'sklearn.ensemble._forest.ExtraTreesClassifier'> and  accuracy score is : 0.74779, balanced accuracy score: 0.59684, recall: 0.90213, precision: 0.79008, f1: 0.8424
# model : <class 'sklearn.naive_bayes.GaussianNB'> and  accuracy score is : 0.47783, balanced accuracy score: 0.54692, recall: 0.40714, precision: 0.79348, f1: 0.53799
# model : <class 'sklearn.ensemble._gb.GradientBoostingClassifier'> and  accuracy score is : 0.7092, balanced accuracy score: 0.5154299999999999, recall: 0.90736, precision: 0.75371, f1: 0.8234
# model : <class 'sklearn.ensemble._hist_gradient_boosting.gradient_boosting.HistGradientBoostingClassifier'> and  accuracy score is : 0.72872, balanced accuracy score: 0.51957, recall: 0.94258, precision: 0.75513, f1: 0.83851
# model : <class 'sklearn.neighbors._classification.KNeighborsClassifier'> and  accuracy score is : 0.57825, balanced accuracy score: 0.5669299999999999, recall: 0.58981, precision: 0.79267, f1: 0.67633
# model : <class 'sklearn.discriminant_analysis.LinearDiscriminantAnalysis'> and  accuracy score is : 0.5613, balanced accuracy score: 0.56089, recall: 0.56175, precision: 0.79051, f1: 0.65676
# model : <class 'sklearn.svm._classes.LinearSVC'> and  accuracy score is : 0.56135, balanced accuracy score: 0.56108, recall: 0.56162, precision: 0.79064, f1: 0.65673
# model : <class 'sklearn.linear_model._logistic.LogisticRegression'> and  accuracy score is : 0.56212, balanced accuracy score: 0.56201, recall: 0.56224, precision: 0.7913, f1: 0.65738
# model : <class 'sklearn.linear_model._logistic.LogisticRegressionCV'> and  accuracy score is : 0.56213, balanced accuracy score: 0.56204, recall: 0.5622199999999999, precision: 0.79133, f1: 0.65738
# model : <class 'sklearn.neural_network._multilayer_perceptron.MLPClassifier'> and  accuracy score is : 0.59849, balanced accuracy score: 0.56791, recall: 0.62975, precision: 0.79061, f1: 0.70044
# model : <class 'sklearn.neighbors._nearest_centroid.NearestCentroid'> and  accuracy score is : 0.55332, balanced accuracy score: 0.54543, recall: 0.56137, precision: 0.77907, f1: 0.65254
# model : <class 'sklearn.linear_model._passive_aggressive.PassiveAggressiveClassifier'> and  accuracy score is : 0.49161, balanced accuracy score: 0.51345, recall: 0.4693, precision: 0.75914, f1: 0.5684899999999999
# model : <class 'sklearn.linear_model._perceptron.Perceptron'> and  accuracy score is : 0.54111, balanced accuracy score: 0.51843, recall: 0.56432, precision: 0.7598400000000001, f1: 0.64619
# model : <class 'sklearn.discriminant_analysis.QuadraticDiscriminantAnalysis'> and  accuracy score is : 0.47225, balanced accuracy score: 0.53526, recall: 0.40782, precision: 0.78136, f1: 0.53583
# model : <class 'sklearn.ensemble._forest.RandomForestClassifier'> and  accuracy score is : 0.74059, balanced accuracy score: 0.57089, recall: 0.91412, precision: 0.7777, f1: 0.84041
# model : <class 'sklearn.linear_model._ridge.RidgeClassifier'> and  accuracy score is : 0.5613, balanced accuracy score: 0.56089, recall: 0.56175, precision: 0.79051, f1: 0.65676
# model : <class 'sklearn.linear_model._ridge.RidgeClassifierCV'> and  accuracy score is : 0.56132, balanced accuracy score: 0.56091, recall: 0.56175, precision: 0.79053, f1: 0.65677
# model : <class 'sklearn.linear_model._stochastic_gradient.SGDClassifier'> and  accuracy score is : 0.54533, balanced accuracy score: 0.55376, recall: 0.53672, precision: 0.78746, f1: 0.63637
# model : <class 'sklearn.svm._classes.SVC'> and  accuracy score is : 0.5901, balanced accuracy score: 0.5778, recall: 0.60265, precision: 0.79937, f1: 0.68721
#                                                     Accuracy  \
# <class 'sklearn.ensemble._weight_boosting.AdaBo...   0.61525
# <class 'sklearn.ensemble._bagging.BaggingClassi...   0.67242
# <class 'sklearn.naive_bayes.BernoulliNB'>            0.54431
# <class 'sklearn.calibration.CalibratedClassifie...   0.32287
# <class 'sklearn.tree._classes.DecisionTreeClass...   0.63425
# <class 'sklearn.dummy.DummyClassifier'>              0.25283
# <class 'sklearn.tree._classes.ExtraTreeClassifi...   0.61832
# <class 'sklearn.ensemble._forest.ExtraTreesClas...   0.74779
# <class 'sklearn.naive_bayes.GaussianNB'>             0.47783
# <class 'sklearn.ensemble._gb.GradientBoostingCl...   0.70920
# <class 'sklearn.ensemble._hist_gradient_boostin...   0.72872
# <class 'sklearn.neighbors._classification.KNeig...   0.57825
# <class 'sklearn.discriminant_analysis.LinearDis...   0.56130
# <class 'sklearn.svm._classes.LinearSVC'>             0.56135
# <class 'sklearn.linear_model._logistic.Logistic...   0.56212
# <class 'sklearn.linear_model._logistic.Logistic...   0.56213
# <class 'sklearn.neural_network._multilayer_perc...   0.59849
# <class 'sklearn.neighbors._nearest_centroid.Nea...   0.55332
# <class 'sklearn.linear_model._passive_aggressiv...   0.49161
# <class 'sklearn.linear_model._perceptron.Percep...   0.54111
# <class 'sklearn.discriminant_analysis.Quadratic...   0.47225
# <class 'sklearn.ensemble._forest.RandomForestCl...   0.74059
# <class 'sklearn.linear_model._ridge.RidgeClassi...   0.56130
# <class 'sklearn.linear_model._ridge.RidgeClassi...   0.56132
# <class 'sklearn.linear_model._stochastic_gradie...   0.54533
# <class 'sklearn.svm._classes.SVC'>                   0.59010
#
#                                                     Balanced Accuracy  \
# <class 'sklearn.ensemble._weight_boosting.AdaBo...            0.55746
# <class 'sklearn.ensemble._bagging.BaggingClassi...            0.56537
# <class 'sklearn.naive_bayes.BernoulliNB'>                     0.55289
# <class 'sklearn.calibration.CalibratedClassifie...            0.45884
# <class 'sklearn.tree._classes.DecisionTreeClass...            0.54976
# <class 'sklearn.dummy.DummyClassifier'>                       0.50000
# <class 'sklearn.tree._classes.ExtraTreeClassifi...            0.55241
# <class 'sklearn.ensemble._forest.ExtraTreesClas...            0.59684
# <class 'sklearn.naive_bayes.GaussianNB'>                      0.54692
# <class 'sklearn.ensemble._gb.GradientBoostingCl...            0.51543
# <class 'sklearn.ensemble._hist_gradient_boostin...            0.51957
# <class 'sklearn.neighbors._classification.KNeig...            0.56693
# <class 'sklearn.discriminant_analysis.LinearDis...            0.56089
# <class 'sklearn.svm._classes.LinearSVC'>                      0.56108
# <class 'sklearn.linear_model._logistic.Logistic...            0.56201
# <class 'sklearn.linear_model._logistic.Logistic...            0.56204
# <class 'sklearn.neural_network._multilayer_perc...            0.56791
# <class 'sklearn.neighbors._nearest_centroid.Nea...            0.54543
# <class 'sklearn.linear_model._passive_aggressiv...            0.51345
# <class 'sklearn.linear_model._perceptron.Percep...            0.51843
# <class 'sklearn.discriminant_analysis.Quadratic...            0.53526
# <class 'sklearn.ensemble._forest.RandomForestCl...            0.57089
# <class 'sklearn.linear_model._ridge.RidgeClassi...            0.56089
# <class 'sklearn.linear_model._ridge.RidgeClassi...            0.56091
# <class 'sklearn.linear_model._stochastic_gradie...            0.55376
# <class 'sklearn.svm._classes.SVC'>                            0.57780
#
#                                                      Recall  Precision  \
# <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.67433    0.78091
# <class 'sklearn.ensemble._bagging.BaggingClassi...  0.78190    0.78021
# <class 'sklearn.naive_bayes.BernoulliNB'>           0.53557    0.78645
# <class 'sklearn.calibration.CalibratedClassifie...  0.18379    0.67113
# <class 'sklearn.tree._classes.DecisionTreeClass...  0.72066    0.77423
# <class 'sklearn.dummy.DummyClassifier'>             0.00000    0.00000
# <class 'sklearn.tree._classes.ExtraTreeClassifi...  0.68575    0.77720
# <class 'sklearn.ensemble._forest.ExtraTreesClas...  0.90213    0.79008
# <class 'sklearn.naive_bayes.GaussianNB'>            0.40714    0.79348
# <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.90736    0.75371
# <class 'sklearn.ensemble._hist_gradient_boostin...  0.94258    0.75513
# <class 'sklearn.neighbors._classification.KNeig...  0.58981    0.79267
# <class 'sklearn.discriminant_analysis.LinearDis...  0.56175    0.79051
# <class 'sklearn.svm._classes.LinearSVC'>            0.56162    0.79064
# <class 'sklearn.linear_model._logistic.Logistic...  0.56224    0.79130
# <class 'sklearn.linear_model._logistic.Logistic...  0.56222    0.79133
# <class 'sklearn.neural_network._multilayer_perc...  0.62975    0.79061
# <class 'sklearn.neighbors._nearest_centroid.Nea...  0.56137    0.77907
# <class 'sklearn.linear_model._passive_aggressiv...  0.46930    0.75914
# <class 'sklearn.linear_model._perceptron.Percep...  0.56432    0.75984
# <class 'sklearn.discriminant_analysis.Quadratic...  0.40782    0.78136
# <class 'sklearn.ensemble._forest.RandomForestCl...  0.91412    0.77770
# <class 'sklearn.linear_model._ridge.RidgeClassi...  0.56175    0.79051
# <class 'sklearn.linear_model._ridge.RidgeClassi...  0.56175    0.79053
# <class 'sklearn.linear_model._stochastic_gradie...  0.53672    0.78746
# <class 'sklearn.svm._classes.SVC'>                  0.60265    0.79937
#
#                                                          f1
# <class 'sklearn.ensemble._weight_boosting.AdaBo...  0.72364
# <class 'sklearn.ensemble._bagging.BaggingClassi...  0.78105
# <class 'sklearn.naive_bayes.BernoulliNB'>           0.63717
# <class 'sklearn.calibration.CalibratedClassifie...  0.28856
# <class 'sklearn.tree._classes.DecisionTreeClass...  0.74646
# <class 'sklearn.dummy.DummyClassifier'>             0.00000
# <class 'sklearn.tree._classes.ExtraTreeClassifi...  0.72857
# <class 'sklearn.ensemble._forest.ExtraTreesClas...  0.84240
# <class 'sklearn.naive_bayes.GaussianNB'>            0.53799
# <class 'sklearn.ensemble._gb.GradientBoostingCl...  0.82340
# <class 'sklearn.ensemble._hist_gradient_boostin...  0.83851
# <class 'sklearn.neighbors._classification.KNeig...  0.67633
# <class 'sklearn.discriminant_analysis.LinearDis...  0.65676
# <class 'sklearn.svm._classes.LinearSVC'>            0.65673
# <class 'sklearn.linear_model._logistic.Logistic...  0.65738
# <class 'sklearn.linear_model._logistic.Logistic...  0.65738
# <class 'sklearn.neural_network._multilayer_perc...  0.70044
# <class 'sklearn.neighbors._nearest_centroid.Nea...  0.65254
# <class 'sklearn.linear_model._passive_aggressiv...  0.56849
# <class 'sklearn.linear_model._perceptron.Percep...  0.64619
# <class 'sklearn.discriminant_analysis.Quadratic...  0.53583
# <class 'sklearn.ensemble._forest.RandomForestCl...  0.84041
# <class 'sklearn.linear_model._ridge.RidgeClassi...  0.65676
# <class 'sklearn.linear_model._ridge.RidgeClassi...  0.65677
# <class 'sklearn.linear_model._stochastic_gradie...  0.63637
# <class 'sklearn.svm._classes.SVC'>                  0.68721
