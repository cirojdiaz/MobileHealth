# %% [markdown]
# # Latest Many to Many ANN Model
# The is the latest ANN model for Fall 2022 Team
#
# Purpose:
# -  This model takes values of heart rate (HR), oxygen saturation (SpO2), normal blood pressure (NBP) and electrocardiogram (ECG) data to predict the same four health metrics simultaneously.
#
#
# Notes:
# - Data was downsampled by 15 to minimize redundancy.
# - Dr. Ciro suggested to build a Many to Many model so it can be applicable in the app.
# - We use previous values to predict future ones, these future values will eventually become previous values.

# %% [markdown]
# # Libraries

# %%
# import libraries
import matplotlib.pyplot as plt
import math
from mpl_toolkits import mplot3d
import numpy as np
import os
import pandas as pd
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
import tensorflow as tf

# %% [markdown]
# # Loading/Preprocessing

# %%
#Importing the data using an environment variable

csv_folder_path = os.environ.get("CSV_Folder_Path")
file_path = os.path.join(csv_folder_path, "uq_vsd_case04_alldata.csv")
# Out:
# Mounted at /content/drive

# %%
# FILTERING THE DATA
df = pd.read_csv(file_path, index_col=False, error_bad_lines=False, usecols=['Time', 'HR', 'SpO2', 'NBP (Mean)', 'ECG'])

df = df.dropna() #drop rows with NaN

case4_filteredData = df.loc[(~df['HR'].isnull()) & (~df['SpO2'].isnull()) & (~df['NBP (Mean)'].isnull()) & (~df['ECG'].isnull())]
case4_filteredData.drop('Time', axis=1, inplace=True)
print(case4_filteredData.head(10))
print(case4_filteredData.tail(10))
print(case4_filteredData.shape)
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version.
#
#
#   exec(code_obj, self.user_global_ns, self.user_ns)
#          HR  SpO2  NBP (Mean)    ECG
# 6758  112.0  97.0        93.0 -0.005
# 6759  112.0  97.0        93.0  0.040
# 6760  112.0  97.0        93.0  0.080
# 6761  112.0  97.0        93.0  0.115
# 6762  112.0  97.0        93.0  0.140
# 6763  112.0  97.0        93.0  0.140
# 6764  112.0  97.0        93.0  0.115
# 6765  112.0  97.0        93.0  0.055
# 6766  112.0  97.0        93.0  0.000
# 6767  112.0  97.0        93.0 -0.035
#            HR   SpO2  NBP (Mean)    ECG
# 837315  131.0  100.0        98.0 -0.005
# 837316  131.0  100.0        98.0 -0.005
# 837317  131.0  100.0        98.0 -0.005
# 837318  131.0  100.0        98.0 -0.005
# 837319  131.0  100.0        98.0 -0.005
# 837320  131.0  100.0        98.0 -0.005
# 837321  131.0  100.0        98.0 -0.005
# 837322  131.0  100.0        98.0 -0.005
# 837323  131.0  100.0        98.0 -0.005
# 837324  131.0  100.0        98.0 -0.005
# (785853, 4)

# %%
# plot data
dataset = case4_filteredData # use if google drive
values = dataset.values

# specify columns to plot
groups = [0,1,2,3]
i =1
for g in groups:
  plt.subplot(len(groups), 1, i)
  plt.plot(values[:, g])
  plt.title(dataset.columns[g], y=0.5, loc='right')
  i += 1
# plt.show()

# %%
# ----------------------------------------------------------------- MANUALLY RESAMPLE -------------------------------------------------------------------
def downsample_data(window):
  df_temp = pd.DataFrame(columns=['HR', 'SpO2', 'NBP (Mean)', 'ECG'])
  HR_sum = 0
  SPO_sum = 0
  NBP_sum = 0
  ECG_sum = 0

  for i in range(1, len(values) - 1):
    HR_sum += values[i, 0]
    SPO_sum += values[i, 1]
    NBP_sum += values[i, 2]
    ECG_sum += values[i, 3]
    if (i + 1) % window == 0:
      HR_sum = HR_sum/window
      SPO_sum = SPO_sum/window
      NBP_sum = NBP_sum/window
      ECG_sum = ECG_sum/window
      row = {'HR':HR_sum, 'SpO2':SPO_sum, 'NBP (Mean)':NBP_sum, 'ECG':ECG_sum}
      df_temp = df_temp.append(row, ignore_index = True)
      HR_sum = 0
      SPO_sum = 0
      NBP_sum = 0
      ECG_sum = 0
  return df_temp

old_data = case4_filteredData
print('Size of old data:')
print(old_data.shape)

# downsampling data
case4_filteredData = downsample_data(15)

print('Size of new data:')
print(case4_filteredData.shape)
# Out:
# Size of old data:
# (785853, 4)
# Size of new data:
# (52390, 4)

# %% [markdown]
# # Functions

# %%
# FUNCTIONS
"""
This functions splits the data into training and test sets.

@param data_df : a Pandas Dataframe that contains the data to be split into training and test sets
@param train_size : a double/float that is within the range of 0 and 1 and represents the fraction of the data to be used for the training set

@returns two Numpy arrays that represent the training and test sets, respectively
"""
def split_data_train_test(data_df, train_size):
  train_df, test_df = data_df[0:round(train_size * len(data_df)), :], data_df[round(train_size * len(data_df)):len(data_df), :]

  return train_df, test_df



"""
This function takes in the data to be scaled and uses Min-Max Scaling.

@param data : a Numpy array that represents the inputted data to be scaled

@returns the scaled data as a Numpy array, the MinMax scaler object, the scaling factor used, and the minimum value of the original inputted data
"""
def minMaxScaling(data):
  scaler = sklearn.preprocessing.MinMaxScaler(feature_range=(0.1, 1))
  scaler.fit(data)

  scaleFactor = scaler.scale_
  data_min = scaler.data_min_
  data_max = scaler.data_max_
  data = scaler.transform(data)

  return data, scaler, scaleFactor, data_min, data_max


"""
This function plots the inputted data in a 2D scatterplot.

@param xvals : a 1D Numpy array that contains the data to be plotted on the x-axis
@param data : a 1D Numpy array that contains the data to be plotted on the y-axis
@param xVariable : a string that represents the label of the data to be plotted for x-axis
@param yVariable : a string that represents the label of the data to be plotted for y-axis
"""
def plot_data(xvals, data, xVariable, yVariable):
  plt.figure(figsize=(10, 5))
  plt.scatter(xvals, data)
  plt.title("Plot of Data for " + yVariable + ", " + xVariable)
  plt.ylabel(yVariable)
  plt.xlabel(xVariable)
  plt.show()


"""
This function plots a loss function based on the output of the model fitting.

@param loss_vals : a Tensorflow History object from model fitting, which is used to get the training and validation loss values
@param startRange : an integer that is >= 0, is within the indices of loss_vals, and represents the start indices of the loss values to plot
@param endRange : an integer that is <= len(loss_vals) - 1, is larger than startRange, and represents the end indices of the loss values to plot
"""
def plot_loss(loss_vals, startRange, endRange):
  plt.figure(figsize=(12, 8))
  plt.plot(loss_vals.history['loss'][startRange:endRange], label="Training Loss") 
  plt.plot(loss_vals.history['val_loss'][startRange:endRange], label="Validation Loss") 
  plt.xlabel("Epoch")
  plt.ylabel("Error")
  plt.title("Learning Curve")
  plt.legend()


"""
This function plots the inputted actual and predicted data in a 2D scatterplot.

@param xvals : a 1D Numpy array that contains the data to be plotted on the x-axis
@param actual_data : a 1D Numpy array that contains the actual data to be plotted on the y-axis
@param predicted_data : a 1D Numpy array that contains the predicted data to be plotted on the y-axis
@param xName : a string that represents the x-values and label for the x-axis
@param yName : a string that represents the y-values and label for the y-axis
"""
def plot_model_data(xvals, actual_data, predicted_data, xName, yName):
  plt.figure(figsize=(12, 8))
  plt.scatter(xvals, actual_data, label="Actual Data", color="r")
  plt.plot(xvals, predicted_data, label="Predicted Data", color="black")
  plt.title("Plot of Model Data for " + xName + " Against " + yName)
  plt.xlabel(xName)
  plt.ylabel(yName)
  plt.legend()



"""
This function plots the inputted actual and predicted data in a 3D scatterplot.

@param x_val : a 1D Numpy array that contains the data to be plotted on the x-axis
@param y_val : a 1D Numpy array that contains the data to be plotted on the y-axis
@param actual_data : a 1D Numpy array that contains the actual data to be plotted on the z-axis
@param predicted_data : a 1D Numpy array that contains the predicted data to be plotted on the z-axis
@param xName : a string that represents the x-values and label for the x-axis
@param yName : a string that represents the y-values and label for the y-axis
@param zName : a string that represents the z-values and label for the z-axis
"""
def plot_model_data3D(x_val, y_val, actual_data, predicted_data, xName, yName, zName):
  fig = plt.figure(figsize=(12, 8))

  ax = plt.axes(projection='3d')
  ax.scatter3D(x_val, y_val, actual_data, label='Actual Data', color="red")
  ax.plot3D(x_val, y_val, predicted_data, label='Predicted Data', color="black")

  ax.set_title("Plot of Model Data for " + xName + " And " + yName + " Against " + zName, pad=20)
  ax.set_xlabel(xName)
  ax.set_ylabel(yName)
  ax.set_zlabel(zName)
  ax.legend()


"""
This functions gets and prints the root mean squared error (RMSE) of the targets.

@param test_targets : a Numpy array that represents the actual target values
@param predicted_targets : a Numpy array that represents the predicted target values

@returns the RMSE double/float value

MANUAL RMSE 
"""
def get_and_print_rmse_for_model(test_targets, predicted_targets):
  mse = sklearn.metrics.mean_squared_error(y_true=test_targets, y_pred=predicted_targets)  
  rmse = math.sqrt(mse)  
  print("RMSE: ", rmse)  
  
  return rmse 
"""
to calculate RMSE manually to add:
"""

#def calculate_rmse_manual(test_targets, predicted_targets):
  
"""
This functions gets and prints the coefficient of determination (R^2) of the targets.

@param test_targets : a Numpy array that represents the actual target values
@param predicted_targets : a Numpy array that represents the predicted target values

@returns the R^2 double/float value
"""

def get_and_print_R2_for_model(test_targets, predicted_targets):
    r2 = sklearn.metrics.r2_score(y_true=test_targets, y_pred=predicted_targets)
    print("R2 (Sklearn): " + str(r2))
  
    return r2



"""
This function uses the mean absolute percentage error (MAPE) to get a percentage error for a regression model. 

Note that if the output is a number above 1 or below 0, usually very big in magnitude, it is because 
some of the numbers in the test_targets are 0 or very close to 0, which gives a division by 0.

@param test_targets : a Numpy array that represents the actual target values
@param predicted_targets : a Numpy array that represents the predicted target values

@returns the MAPE double/float value which represents the decimal form of the percentage, so generally between 0 and 1
"""

def get_and_print_mape_for_model(test_targets, predicted_targets):
  mape = sklearn.metrics.mean_absolute_percentage_error(test_targets, predicted_targets)
  print("MAPE: " + str(mape))

  return mape



"""
This function gets the mean absolute error (MAE) for a regression model. 

Note that if the output is a number below 0, usually very big in magnitude, it is because 
some of the numbers in the test_targets are 0 or very close to 0, which gives a division by 0.

@param test_targets : a Numpy array that represents the actual target values
@param predicted_targets : a Numpy array that represents the predicted target values

@returns the MAPE double/float value, which should be greater than or equal to 0
"""
def get_and_print_mae_for_model(test_targets, predicted_targets):
  mae = sklearn.metrics.mean_absolute_error(test_targets, predicted_targets)
  print("MAE: " + str(mae))

  return mae



"""
This functions plots the actual and predicted values as a line plot.

@param indices : the x-values of the plot as a 1-column Numpy array
@param test_targets : a 1-column Numpy array that represents the actual target values
@param predicted_targets : a 1-column Numpy array that represents the predicted target values
"""
def plot_actual_and_predictions_line(x_val, test_targets, predicted_targets):
  # fig = plt.figure(figsize=(12, 8))
  # fig2 = plt.figure(figsize=(12, 8))
  
  # HR
  fig = plt.figure(figsize=(12, 8))
  plt.plot(x_val, test_targets[:, 0], label="Actual HR", c="b", linestyle="dashed")
  plt.plot(x_val, predicted_targets[:, 0], label="Predicted HR", c="lightblue", linestyle="dashed")
  plt.ylabel("HR Values")
  plt.title("Plot of Actual and Predicted Values - HR")
  plt.legend()

  # SPO2
  fig2 = plt.figure(figsize=(12, 8))
  plt.plot(x_val, test_targets[:, 1], label="Actual SPO2", c="purple")
  plt.plot(x_val, predicted_targets[:, 1], label="Predicted SPO2", c="lavender")
  plt.ylabel("SPO2 Values")
  plt.title("Plot of Actual and Predicted Values - SPO2")
  plt.legend()

  # NBP
  fig3 = plt.figure(figsize=(12, 8))
  plt.plot(x_val, test_targets[:, 2], label="Actual NBP", c="g")
  plt.plot(x_val, predicted_targets[:, 2], label="Predicted NBP", c="lightgreen")
  plt.ylabel("NBP Values")
  plt.title("Plot of Actual and Predicted Values - NBP")
  plt.legend()

  # ECG
  fig4 = plt.figure(figsize=(12, 8))
  plt.plot(x_val, test_targets[:, 3], label="Actual ECG", c="r")
  plt.plot(x_val, predicted_targets[:, 3], label="Predicted ECG", c="pink")
  plt.ylabel("ECG Values")
  plt.title("Plot of Actual and Predicted Values - ECG")
  plt.legend()

  # plt.ylabel("Values")
  # plt.title("Plot of Actual and Predicted Values")
  # plt.legend()
  plt.show()



"""
This functions plots the actual and predicted values as a scatter plot.

@param indices : a 1-column Numpy array that represents x-values of the plot 
@param test_targets : a 1-column Numpy array that represents the actual target values
@param predicted_targets : a 1-column Numpy array that represents the predicted target values
"""
def plot_actual_and_predictions_scatter(x_val, test_targets, predicted_targets):
  fig = plt.figure(figsize=(12, 8))
  plt.scatter(x_val, test_targets, label="Actual Values", c="b")
  plt.scatter(x_val, predicted_targets, label="Predicted Values", c="r")

  plt.ylabel("Value")
  plt.title("Plot of Actual and Predicted Values")
  plt.legend()



"""
This function makes a custom artificial neural network model.

@param train_features : a Numpy array that represents the training data features
@param train_labels : a Numpy array that represents the training data targets
@param numOfUnits : a list that contains the number of units for each layer, which could be customized by providing different integers in the desired order. 
                    The size of the list should either be equal to 1 or numOfLayers. If size = 1, then all layers will have that number of units in the list.
                    (eg. [4, 8, 16] if numOfLayers = 3, or [4] for any value of numOfLayers)
@param numOfLayers : an integer that represents the desired of layers to add to the model 
@param epochNum : the number of iterations/epochs for running the model
@param learning_rate : a double/float that represents the learning rate of the model

@returns the artificial neural network TensorFlow model and the result from fitting the model

"""
def make_custom_ANN(train_features, train_labels, numOfUnits=[4], numOfLayers=3, batchNum=None, epochNum=100, learning_rate=0.01, min_delta=0.0007):
  callback_valLoss = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=1, min_delta=min_delta, mode='min', verbose=1)
  callback_trainLoss = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=1, min_delta=min_delta, mode='min', verbose=1)

  # ann_model = tf.keras.Sequential()
  limit = numOfLayers

  if (len(numOfUnits) is not numOfLayers) and (len(numOfUnits) is not 1):
    raise Exception("Invalid input for numOfUnits.")
  
  for i in range(0, limit):
    if len(numOfUnits) is numOfLayers:
      numUnits = numOfUnits[i]
    
    else:
      numUnits = numOfUnits[0]
  
  ann_model = tf.keras.models.Sequential([
    tf.keras.layers.Normalization(axis=-1),
    tf.keras.layers.Convolution1D(64, 3, activation='relu'), # add convolutional layer (filters, kernel size) 
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=512, activation="relu"),
    tf.keras.layers.Dense(units=512, activation="relu"),
    tf.keras.layers.Dense(units=512, activation="relu"),
    tf.keras.layers.Dense(4) # default activation of 'linear'
    ])

  ann_model.compile(optimizer=tf.optimizers.Adam(learning_rate=learning_rate),
                    loss='mean_squared_error', metrics=['accuracy'])
  
  ann_model_fit = ann_model.fit(train_features, train_labels, batch_size=batchNum, epochs=epochNum, validation_split=0.3, callbacks=[callback_valLoss, callback_trainLoss])
  

  return ann_model, ann_model_fit


"""
This function splits the training and test sets and turns a certain number of previous values as "features" and the next value as the "target"

@param train_array : a Numpy array with at least 2 columns of the training set values
@param test_array : a Numpy array with at least 2 columns of the test set values
@param numOfPrevValues : an integer that represents the number of previous rows of values to use as features
@param targetIndex : an integer that represents the column number to use for target values

@returns four Numpy arrays for the previous values in the training set, the next 1 value in the training set, the previous values
         in the test set, and the next 1 value in the test set
"""
def splitDataToFeaturesTargetValues(train_array, test_array, numOfPrevValues=3, targetIndex=1):

  # prevData - features
  # nextData - labels

  prevData_train = []
  nextData_train = [] 
  prevData_test = []
  nextData_test = []

  for i in range(numOfPrevValues, len(train_array)):
    prevData_train.append(train_array[i-numOfPrevValues: i]) # append features as it's appending alls rows
    nextData_train.append(train_array[i]) # append label as it's only the row at the target colun

  # don't want to split test data this way
  for j in range(numOfPrevValues, len(test_array)):
    prevData_test.append(test_array[j-numOfPrevValues: j])
    nextData_test.append(test_array[j])  

  prevData_train = np.array(prevData_train)
  nextData_train = np.array(nextData_train).reshape(len(nextData_train), 4)
  print("TRAIN")
  print(f"This is shape of train features array: {prevData_train.shape}")
  print(f"This is shape of train labels array: {nextData_train.shape}")

  prevData_test = np.array(prevData_test)
  nextData_test = np.array(nextData_test).reshape(len(nextData_test), 4) # used to be 1d array w many columns but one row, now it's many rows 1 column so it's a 2d array i think
  print("TEST")
  print(f"This is shape of test features array: {prevData_test.shape}")
  print(f"This is shape of test labels array: {nextData_test.shape}")

  return prevData_train, nextData_train, prevData_test, nextData_test
# Out:
# <>:283: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <>:283: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# <ipython-input-7-3b613f9e496c>:283: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   if (len(numOfUnits) is not numOfLayers) and (len(numOfUnits) is not 1):

# %% [markdown]
# # ANN Model

# %%
# Scaling and splitting dataset, using R-Wave Voltages and SpO2 as features
# pd.set_option("max_rows", 1000)
print(case4_filteredData.head(20))

case4_filteredData_arr_scaled, minMaxScaler, minMaxScaleFactor, case4_filteredData_min, case4_filteredData_max = minMaxScaling(case4_filteredData)
print("case 4 max: "), print(case4_filteredData_max)
print("case 4 min: "), print(case4_filteredData_min)

# Add more columns names if more health variables are added.
case4_filteredData_scaled = pd.DataFrame(case4_filteredData_arr_scaled, columns=["HR", "SpO2","NBP (Mean)","ECG"])

# print()
# print(case4_filteredData_scaled[0:20])

listOfVariables = ["HR", "SpO2","NBP (Mean)","ECG"] # Add more columns names if more health variables are added.
listOfVariables_len = len(listOfVariables) - 1 

data_train, data_test = split_data_train_test(np.array(case4_filteredData_scaled[listOfVariables]), train_size=0.8) # scaled data

print("\nOriginal data train: ")
print(data_train[0:20])

print(" Original test")
print(data_test[0:20])

print(" Here to see the size of each data: ")
print("This is the size of the train data: ")
print(data_train.shape)
print("This is the size of the test data: ")
print(data_test.shape)
# Out:
#             HR       SpO2  NBP (Mean)       ECG
# 0   104.533333  90.533333        86.8  0.013333
# 1   112.000000  97.000000        93.0 -0.021333
# 2   112.000000  97.000000        93.0  0.071000
# 3   112.000000  97.000000        93.0  0.014667
# 4   112.000000  97.000000        93.0 -0.050333
# 5   112.000000  97.000000        93.0  0.083333
# 6   112.266667  97.000000        93.0 -0.204333
# 7   114.000000  97.000000        93.0 -0.159000
# 8   114.000000  97.000000        93.0 -0.192000
# 9   114.000000  97.000000        93.0 -0.077333
# 10  114.000000  97.000000        93.0 -0.103333
# 11  114.000000  97.000000        93.0 -0.096333
# 12  114.000000  97.000000        93.0  0.129000
# 13  114.333333  97.333333        93.0 -0.058000
# 14  115.000000  98.000000        93.0  0.198000
# 15  115.000000  98.000000        93.0  0.166333
# 16  115.000000  98.000000        93.0  0.231667
# 17  115.000000  98.000000        93.0  0.188667
# 18  115.000000  98.000000        93.0  0.103333
# 19  115.000000  98.000000        93.0  0.291667
# case 4 max:
# [141.         100.         123.          16.65366667]
# case 4 min:
# [ 70.          90.53333333  59.         -15.27866667]
#
# Original data train:
# [[0.53774648 0.1        0.4909375  0.53099888]
#  [0.63239437 0.71478873 0.578125   0.53002182]
#  [0.63239437 0.71478873 0.578125   0.53262419]
#  [0.63239437 0.71478873 0.578125   0.53103646]
#  [0.63239437 0.71478873 0.578125   0.52920446]
#  [0.63239437 0.71478873 0.578125   0.5329718 ]
#  [0.63577465 0.71478873 0.578125   0.52486404]
#  [0.65774648 0.71478873 0.578125   0.52614174]
#  [0.65774648 0.71478873 0.578125   0.52521165]
#  [0.65774648 0.71478873 0.578125   0.52844348]
#  [0.65774648 0.71478873 0.578125   0.52771068]
#  [0.65774648 0.71478873 0.578125   0.52790797]
#  [0.65774648 0.71478873 0.578125   0.5342589 ]
#  [0.66197183 0.74647887 0.578125   0.52898838]
#  [0.67042254 0.80985915 0.578125   0.53620364]
#  [0.67042254 0.80985915 0.578125   0.53531113]
#  [0.67042254 0.80985915 0.578125   0.53715252]
#  [0.67042254 0.80985915 0.578125   0.53594058]
#  [0.67042254 0.80985915 0.578125   0.5335355 ]
#  [0.67042254 0.80985915 0.578125   0.5388436 ]]
#  Original test
# [[0.65774648 0.80985915 0.3390625  0.53807322]
#  [0.65774648 0.80985915 0.3390625  0.53788532]
#  [0.65774648 0.80985915 0.3390625  0.54089168]
#  [0.65774648 0.80985915 0.3390625  0.5320605 ]
#  [0.65774648 0.80985915 0.3390625  0.53343215]
#  [0.65774648 0.80985915 0.3390625  0.53270875]
#  [0.65774648 0.80985915 0.3390625  0.53339457]
#  [0.65774648 0.80985915 0.3390625  0.53038822]
#  [0.65774648 0.80985915 0.3390625  0.53016274]
#  [0.65774648 0.80985915 0.3390625  0.53492594]
#  [0.65774648 0.80985915 0.3390625  0.52814284]
#  [0.65774648 0.80985915 0.3390625  0.53040701]
#  [0.65605634 0.80985915 0.3390625  0.53109283]
#  [0.64507042 0.80985915 0.3390625  0.534071  ]
#  [0.64507042 0.80985915 0.3390625  0.53047277]
#  [0.64507042 0.80985915 0.3390625  0.53201353]
#  [0.64507042 0.80985915 0.3390625  0.53739679]
#  [0.64507042 0.80985915 0.3390625  0.52909173]
#  [0.64507042 0.80985915 0.3390625  0.53281209]
#  [0.64507042 0.80985915 0.3390625  0.53262419]]
#  Here to see the size of each data:
# This is the size of the train data:
# (41912, 4)
# This is the size of the test data:
# (10478, 4)

# %% [markdown]
# ##Artificial Neural Network Model for Using HR, SpO2, NBP (Mean), ECG to Predict All 4 simultaneously

# %%
# Splitting to features and labels

data_train_features, data_train_label, data_test_features, data_test_label = splitDataToFeaturesTargetValues(data_train, data_test, numOfPrevValues=500)

# batch_num = int(len(data_train_label) / 1350)
batch_num = None
epochNum = 5000
learn_rate = 0.000001
numOfUnits_list = [512]

# Running the ANN model
ann_model_hr, ann_model_hr_fit = make_custom_ANN(data_train_features, data_train_label, numOfUnits=numOfUnits_list, batchNum=batch_num,
                                           numOfLayers=3, epochNum=epochNum, learning_rate=learn_rate, min_delta=0.0001)

plot_loss(ann_model_hr_fit, 0, epochNum)
ann_model_hr.summary()
# Out:
# TRAIN
# This is shape of train features array: (41412, 500, 4)
# This is shape of train labels array: (41412, 4)
# TEST
# This is shape of test features array: (9978, 500, 4)
# This is shape of test labels array: (9978, 4)
# Epoch 1/5000
# 906/906 [==============================] - 156s 171ms/step - loss: 0.0253 - accuracy: 0.8445 - val_loss: 7.7719e-04 - val_accuracy: 0.9163
# Epoch 2/5000
# 906/906 [==============================] - 152s 168ms/step - loss: 0.0019 - accuracy: 0.8838 - val_loss: 5.4675e-04 - val_accuracy: 0.9017
# Epoch 3/5000
# 906/906 [==============================] - 153s 169ms/step - loss: 0.0011 - accuracy: 0.9051 - val_loss: 5.2911e-04 - val_accuracy: 0.7773
# Epoch 3: early stopping
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  normalization_1 (Normalizat  (None, 500, 4)           9
#  ion)
#
#  conv1d_1 (Conv1D)           (None, 498, 64)           832
#
#  flatten_1 (Flatten)         (None, 31872)             0
#
#  dense_4 (Dense)             (None, 512)               16318976
#
#  dense_5 (Dense)             (None, 512)               262656
#
#  dense_6 (Dense)             (None, 512)               262656
#
#  dense_7 (Dense)             (None, 4)                 2052
#
# =================================================================
# Total params: 16,847,181
# Trainable params: 16,847,172
# Non-trainable params: 9
# _________________________________________________________________

# %%
print(data_train_features.shape) # input shape into predictions
print(data_test_features.shape)
print(data_test_features)
# Out:
# (41412, 500, 4)
# (9978, 500, 4)
# [[[0.65774648 0.80985915 0.3390625  0.53807322]
#   [0.65774648 0.80985915 0.3390625  0.53788532]
#   [0.65774648 0.80985915 0.3390625  0.54089168]
#   ...
#   [0.65774648 0.90492958 0.353125   0.52975876]
#   [0.65774648 0.90492958 0.353125   0.53299999]
#   [0.65774648 0.90492958 0.353125   0.53003121]]
#
#  [[0.65774648 0.80985915 0.3390625  0.53788532]
#   [0.65774648 0.80985915 0.3390625  0.54089168]
#   [0.65774648 0.80985915 0.3390625  0.5320605 ]
#   ...
#   [0.65774648 0.90492958 0.353125   0.53299999]
#   [0.65774648 0.90492958 0.353125   0.53003121]
#   [0.65774648 0.90492958 0.353125   0.52981513]]
#
#  [[0.65774648 0.80985915 0.3390625  0.54089168]
#   [0.65774648 0.80985915 0.3390625  0.5320605 ]
#   [0.65774648 0.80985915 0.3390625  0.53343215]
#   ...
#   [0.65774648 0.90492958 0.353125   0.53003121]
#   [0.65774648 0.90492958 0.353125   0.52981513]
#   [0.65774648 0.90492958 0.353125   0.53509504]]
#
#  ...
#
#  [[0.73380282 1.         0.7046875  0.53805443]
#   [0.73380282 1.         0.7046875  0.54152113]
#   [0.73380282 1.         0.7046875  0.53667338]
#   ...
#   [0.87323944 1.         0.6484375  0.53048217]
#   [0.87323944 1.         0.6484375  0.53048217]
#   [0.87323944 1.         0.6484375  0.53048217]]
#
#  [[0.73380282 1.         0.7046875  0.54152113]
#   [0.73380282 1.         0.7046875  0.53667338]
#   [0.73380282 1.         0.7046875  0.53925697]
#   ...
#   [0.87323944 1.         0.6484375  0.53048217]
#   [0.87323944 1.         0.6484375  0.53048217]
#   [0.87323944 1.         0.6484375  0.53048217]]
#
#  [[0.73380282 1.         0.7046875  0.53667338]
#   [0.73380282 1.         0.7046875  0.53925697]
#   [0.73380282 1.         0.7046875  0.53750013]
#   ...
#   [0.87323944 1.         0.6484375  0.53048217]
#   [0.87323944 1.         0.6484375  0.53048217]
#   [0.87323944 1.         0.6484375  0.53048217]]]

# %%
# Predicting with the model for All 4 metrics - training set - ANN

# making the predictions  -------------------------------------------------------------------------------------
print("\nFor training set:\n")
predictions = ann_model_hr.predict(data_train_features)
print("Shape of predictions BEFORE reshape: "), print(predictions.shape)
print(predictions)

# reshape into 2d array? into the shape of the train features which is 3d
# predictions = predictions.reshape(data_train_features.shape[0], data_train_features.shape[1], data_train_features.shape[2]) # current shape is (length, numOfPrevValues, 1) - new shape (length, numOfPrevValues, 4)
# predictions = predictions[:, 0] # getting values for the next time step (t) and not (t+1, t+2, or t+3)
# predictions = np.reshape(predictions, newshape=(len(predictions), 1))

# plotting accuracies and losses -------------------------------------------------------------------------------
get_and_print_rmse_for_model(data_train_label, predictions)
get_and_print_R2_for_model(data_train_label, predictions)
get_and_print_mae_for_model(data_train_label, predictions)
get_and_print_mape_for_model(data_train_label, predictions)

plot_actual_and_predictions_line(np.arange(0, len(data_train_label)), data_train_label, predictions)
# plot_actual_and_predictions_scatter(np.arange(0, len(data_train_label)), data_train_label, predictions)

print("\nAfter reversing the scaling:\n")

# For if MinMaxScaler was used; change the column number/index to get the values for other health variables
predictions_reversed = ((predictions - 0.1) / (1 - 0.1)) * (case4_filteredData_max[3] - case4_filteredData_min[3]) + case4_filteredData_min[3]
data_train_label_reversed = ((data_train_label - 0.1) / (1 - 0.1)) * (case4_filteredData_max[3] - case4_filteredData_min[3]) + case4_filteredData_min[3]
# data_train_features_reversed = ((data_train_features - 0.1) / (1 - 0.1)) * (combinedData_max[0] - combinedData_min[0]) + combinedData_min[0]

# For if standard scaling was used; change the column number/index to get the values for other health variables
# predictions_reversed = predictions * combinedData_stdDev[1] + combinedData_mean[1]
# data_train_label_reversed = data_train_label * combinedData_stdDev[1] + combinedData_mean[1]
# data_train_features_reversed = data_train_features * combinedData_stdDev[0] + combinedData_mean[0]

get_and_print_rmse_for_model(data_train_label_reversed, predictions_reversed)
get_and_print_R2_for_model(data_train_label_reversed, predictions_reversed)
get_and_print_mae_for_model(data_train_label_reversed, predictions_reversed)
get_and_print_mape_for_model(data_train_label_reversed, predictions_reversed)
# Out:
# For training set:
#
# 1295/1295 [==============================] - 44s 34ms/step
# Shape of predictions BEFORE reshape:
# (41412, 4)
# [[0.57644    0.9008479  0.5647084  0.51886487]
#  [0.5739471  0.8994205  0.56333417 0.5192526 ]
#  [0.57242167 0.8985537  0.5656405  0.5180324 ]
#  ...
#  [0.6698644  0.7980897  0.33559102 0.5184143 ]
#  [0.67240393 0.7995274  0.33415535 0.516624  ]
#  [0.67267025 0.8009789  0.33364588 0.51604635]]
# RMSE:  0.02795504827787001
# R2 (Sklearn): 0.42548230814063126
# MAE: 0.015190893453451525
# MAPE: 0.031869713929889056
# After reversing the scaling:
#
# RMSE:  0.9918554395460585
# R2 (Sklearn): 0.4254822871277363
# MAE: 0.5389784948892038
# MAPE: 313892004463.4712
# 313892004463.4712

# %%
# Predicting with the model for All 4 metrics - test set - ANN ---------------- NEW METHOD

print("\nFor testing set:\n")

# set initial values
numOfPrevValues = 500
batch = []
all_values = []

# ALL IMPLEMENTED INTO THE LOOP
for i in range(0, len(data_test_features) - numOfPrevValues):
  print(i)
  # 1. set the batch accordingly
  if i == 0:
    # only first batch comes from data_test features
    batch = data_test_features[0]
    all_values = batch
  else:
    batch = all_values[i:]

  # 2. reshape the batch
  # old shape (2d) - (27,4)
  # new shape (3d) - (1,27,4) - need to be 3d because shape of model input is also 3d 
  batch = batch.reshape(1, data_test_features[0].shape[0], data_test_features[0].shape[1])

  # 3. make the prediction
  predicted_val = ann_model_hr.predict(batch)
  # revert reshaping to 2d
  batch = batch.reshape(data_test_features[0].shape[0], data_test_features[0].shape[1])

  # 4. append to all values array
  # all_values = batch
  all_values = np.append(all_values, [predicted_val[0]], axis=0)
  all_values = np.array(all_values)

  # 5. print everything
  print(f"LOOP #{i}:")
  print(f"Batch {i} shape: {batch.shape}")
  # print(batch)
  print(f"Predicted {i} shape: {predicted_val.shape}")
  # print(predicted_val)
  print(f"All predicted values shape: {all_values.shape}")
  # print(all_values)
# Out:
# Streaming output truncated to the last 5000 lines.
# Predicted 8644 shape: (1, 4)
# All predicted values shape: (9145, 4)
# 8645
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8645:
# Batch 8645 shape: (500, 4)
# Predicted 8645 shape: (1, 4)
# All predicted values shape: (9146, 4)
# 8646
# 1/1 [==============================] - 0s 36ms/step
# LOOP #8646:
# Batch 8646 shape: (500, 4)
# Predicted 8646 shape: (1, 4)
# All predicted values shape: (9147, 4)
# 8647
# 1/1 [==============================] - 0s 34ms/step
# LOOP #8647:
# Batch 8647 shape: (500, 4)
# Predicted 8647 shape: (1, 4)
# All predicted values shape: (9148, 4)
# 8648
# 1/1 [==============================] - 0s 32ms/step
# LOOP #8648:
# Batch 8648 shape: (500, 4)
# Predicted 8648 shape: (1, 4)
# All predicted values shape: (9149, 4)
# 8649
# 1/1 [==============================] - 0s 34ms/step
# LOOP #8649:
# Batch 8649 shape: (500, 4)
# Predicted 8649 shape: (1, 4)
# All predicted values shape: (9150, 4)
# 8650
# 1/1 [==============================] - 0s 36ms/step
# LOOP #8650:
# Batch 8650 shape: (500, 4)
# Predicted 8650 shape: (1, 4)
# All predicted values shape: (9151, 4)
# 8651
# 1/1 [==============================] - 0s 34ms/step
# LOOP #8651:
# Batch 8651 shape: (500, 4)
# Predicted 8651 shape: (1, 4)
# All predicted values shape: (9152, 4)
# 8652
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8652:
# Batch 8652 shape: (500, 4)
# Predicted 8652 shape: (1, 4)
# All predicted values shape: (9153, 4)
# 8653
# 1/1 [==============================] - 0s 33ms/step
# LOOP #8653:
# Batch 8653 shape: (500, 4)
# Predicted 8653 shape: (1, 4)
# All predicted values shape: (9154, 4)
# 8654
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8654:
# Batch 8654 shape: (500, 4)
# Predicted 8654 shape: (1, 4)
# All predicted values shape: (9155, 4)
# 8655
# 1/1 [==============================] - 0s 28ms/step
# LOOP #8655:
# Batch 8655 shape: (500, 4)
# Predicted 8655 shape: (1, 4)
# All predicted values shape: (9156, 4)
# 8656
# 1/1 [==============================] - 0s 34ms/step
# LOOP #8656:
# Batch 8656 shape: (500, 4)
# Predicted 8656 shape: (1, 4)
# All predicted values shape: (9157, 4)
# 8657
# 1/1 [==============================] - 0s 32ms/step
# LOOP #8657:
# Batch 8657 shape: (500, 4)
# Predicted 8657 shape: (1, 4)
# All predicted values shape: (9158, 4)
# 8658
# 1/1 [==============================] - 0s 28ms/step
# LOOP #8658:
# Batch 8658 shape: (500, 4)
# Predicted 8658 shape: (1, 4)
# All predicted values shape: (9159, 4)
# 8659
# 1/1 [==============================] - 0s 28ms/step
# LOOP #8659:
# Batch 8659 shape: (500, 4)
# Predicted 8659 shape: (1, 4)
# All predicted values shape: (9160, 4)
# 8660
# 1/1 [==============================] - 0s 41ms/step
# LOOP #8660:
# Batch 8660 shape: (500, 4)
# Predicted 8660 shape: (1, 4)
# All predicted values shape: (9161, 4)
# 8661
# 1/1 [==============================] - 0s 32ms/step
# LOOP #8661:
# Batch 8661 shape: (500, 4)
# Predicted 8661 shape: (1, 4)
# All predicted values shape: (9162, 4)
# 8662
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8662:
# Batch 8662 shape: (500, 4)
# Predicted 8662 shape: (1, 4)
# All predicted values shape: (9163, 4)
# 8663
# 1/1 [==============================] - 0s 33ms/step
# LOOP #8663:
# Batch 8663 shape: (500, 4)
# Predicted 8663 shape: (1, 4)
# All predicted values shape: (9164, 4)
# 8664
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8664:
# Batch 8664 shape: (500, 4)
# Predicted 8664 shape: (1, 4)
# All predicted values shape: (9165, 4)
# 8665
# 1/1 [==============================] - 0s 29ms/step
# LOOP #8665:
# Batch 8665 shape: (500, 4)
# Predicted 8665 shape: (1, 4)
# All predicted values shape: (9166, 4)
# 8666
# 1/1 [==============================] - 0s 29ms/step
# LOOP #8666:
# Batch 8666 shape: (500, 4)
# Predicted 8666 shape: (1, 4)
# All predicted values shape: (9167, 4)
# 8667
# 1/1 [==============================] - 0s 39ms/step
# LOOP #8667:
# Batch 8667 shape: (500, 4)
# Predicted 8667 shape: (1, 4)
# All predicted values shape: (9168, 4)
# 8668
# 1/1 [==============================] - 0s 38ms/step
# LOOP #8668:
# Batch 8668 shape: (500, 4)
# Predicted 8668 shape: (1, 4)
# All predicted values shape: (9169, 4)
# 8669
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8669:
# Batch 8669 shape: (500, 4)
# Predicted 8669 shape: (1, 4)
# All predicted values shape: (9170, 4)
# 8670
# 1/1 [==============================] - 0s 29ms/step
# LOOP #8670:
# Batch 8670 shape: (500, 4)
# Predicted 8670 shape: (1, 4)
# All predicted values shape: (9171, 4)
# 8671
# 1/1 [==============================] - 0s 37ms/step
# LOOP #8671:
# Batch 8671 shape: (500, 4)
# Predicted 8671 shape: (1, 4)
# All predicted values shape: (9172, 4)
# 8672
# 1/1 [==============================] - 0s 33ms/step
# LOOP #8672:
# Batch 8672 shape: (500, 4)
# Predicted 8672 shape: (1, 4)
# All predicted values shape: (9173, 4)
# 8673
# 1/1 [==============================] - 0s 32ms/step
# LOOP #8673:
# Batch 8673 shape: (500, 4)
# Predicted 8673 shape: (1, 4)
# All predicted values shape: (9174, 4)
# 8674
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8674:
# Batch 8674 shape: (500, 4)
# Predicted 8674 shape: (1, 4)
# All predicted values shape: (9175, 4)
# 8675
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8675:
# Batch 8675 shape: (500, 4)
# Predicted 8675 shape: (1, 4)
# All predicted values shape: (9176, 4)
# 8676
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8676:
# Batch 8676 shape: (500, 4)
# Predicted 8676 shape: (1, 4)
# All predicted values shape: (9177, 4)
# 8677
# 1/1 [==============================] - 0s 27ms/step
# LOOP #8677:
# Batch 8677 shape: (500, 4)
# Predicted 8677 shape: (1, 4)
# All predicted values shape: (9178, 4)
# 8678
# 1/1 [==============================] - 0s 29ms/step
# LOOP #8678:
# Batch 8678 shape: (500, 4)
# Predicted 8678 shape: (1, 4)
# All predicted values shape: (9179, 4)
# 8679
# 1/1 [==============================] - 0s 32ms/step
# LOOP #8679:
# Batch 8679 shape: (500, 4)
# Predicted 8679 shape: (1, 4)
# All predicted values shape: (9180, 4)
# 8680
# 1/1 [==============================] - 0s 29ms/step
# LOOP #8680:
# Batch 8680 shape: (500, 4)
# Predicted 8680 shape: (1, 4)
# All predicted values shape: (9181, 4)
# 8681
# 1/1 [==============================] - 0s 28ms/step
# LOOP #8681:
# Batch 8681 shape: (500, 4)
# Predicted 8681 shape: (1, 4)
# All predicted values shape: (9182, 4)
# 8682
# 1/1 [==============================] - 0s 32ms/step
# LOOP #8682:
# Batch 8682 shape: (500, 4)
# Predicted 8682 shape: (1, 4)
# All predicted values shape: (9183, 4)
# 8683
# 1/1 [==============================] - 0s 32ms/step
# LOOP #8683:
# Batch 8683 shape: (500, 4)
# Predicted 8683 shape: (1, 4)
# All predicted values shape: (9184, 4)
# 8684
# 1/1 [==============================] - 0s 29ms/step
# LOOP #8684:
# Batch 8684 shape: (500, 4)
# Predicted 8684 shape: (1, 4)
# All predicted values shape: (9185, 4)
# 8685
# 1/1 [==============================] - 0s 29ms/step
# LOOP #8685:
# Batch 8685 shape: (500, 4)
# Predicted 8685 shape: (1, 4)
# All predicted values shape: (9186, 4)
# 8686
# 1/1 [==============================] - 0s 28ms/step
# LOOP #8686:
# Batch 8686 shape: (500, 4)
# Predicted 8686 shape: (1, 4)
# All predicted values shape: (9187, 4)
# 8687
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8687:
# Batch 8687 shape: (500, 4)
# Predicted 8687 shape: (1, 4)
# All predicted values shape: (9188, 4)
# 8688
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8688:
# Batch 8688 shape: (500, 4)
# Predicted 8688 shape: (1, 4)
# All predicted values shape: (9189, 4)
# 8689
# 1/1 [==============================] - 0s 38ms/step
# LOOP #8689:
# Batch 8689 shape: (500, 4)
# Predicted 8689 shape: (1, 4)
# All predicted values shape: (9190, 4)
# 8690
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8690:
# Batch 8690 shape: (500, 4)
# Predicted 8690 shape: (1, 4)
# All predicted values shape: (9191, 4)
# 8691
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8691:
# Batch 8691 shape: (500, 4)
# Predicted 8691 shape: (1, 4)
# All predicted values shape: (9192, 4)
# 8692
# 1/1 [==============================] - 0s 28ms/step
# LOOP #8692:
# Batch 8692 shape: (500, 4)
# Predicted 8692 shape: (1, 4)
# All predicted values shape: (9193, 4)
# 8693
# 1/1 [==============================] - 0s 34ms/step
# LOOP #8693:
# Batch 8693 shape: (500, 4)
# Predicted 8693 shape: (1, 4)
# All predicted values shape: (9194, 4)
# 8694
# 1/1 [==============================] - 0s 39ms/step
# LOOP #8694:
# Batch 8694 shape: (500, 4)
# Predicted 8694 shape: (1, 4)
# All predicted values shape: (9195, 4)
# 8695
# 1/1 [==============================] - 0s 33ms/step
# LOOP #8695:
# Batch 8695 shape: (500, 4)
# Predicted 8695 shape: (1, 4)
# All predicted values shape: (9196, 4)
# 8696
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8696:
# Batch 8696 shape: (500, 4)
# Predicted 8696 shape: (1, 4)
# All predicted values shape: (9197, 4)
# 8697
# 1/1 [==============================] - 0s 32ms/step
# LOOP #8697:
# Batch 8697 shape: (500, 4)
# Predicted 8697 shape: (1, 4)
# All predicted values shape: (9198, 4)
# 8698
# 1/1 [==============================] - 0s 35ms/step
# LOOP #8698:
# Batch 8698 shape: (500, 4)
# Predicted 8698 shape: (1, 4)
# All predicted values shape: (9199, 4)
# 8699
# 1/1 [==============================] - 0s 34ms/step
# LOOP #8699:
# Batch 8699 shape: (500, 4)
# Predicted 8699 shape: (1, 4)
# All predicted values shape: (9200, 4)
# 8700
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8700:
# Batch 8700 shape: (500, 4)
# Predicted 8700 shape: (1, 4)
# All predicted values shape: (9201, 4)
# 8701
# 1/1 [==============================] - 0s 33ms/step
# LOOP #8701:
# Batch 8701 shape: (500, 4)
# Predicted 8701 shape: (1, 4)
# All predicted values shape: (9202, 4)
# 8702
# 1/1 [==============================] - 0s 29ms/step
# LOOP #8702:
# Batch 8702 shape: (500, 4)
# Predicted 8702 shape: (1, 4)
# All predicted values shape: (9203, 4)
# 8703
# 1/1 [==============================] - 0s 33ms/step
# LOOP #8703:
# Batch 8703 shape: (500, 4)
# Predicted 8703 shape: (1, 4)
# All predicted values shape: (9204, 4)
# 8704
# 1/1 [==============================] - 0s 33ms/step
# LOOP #8704:
# Batch 8704 shape: (500, 4)
# Predicted 8704 shape: (1, 4)
# All predicted values shape: (9205, 4)
# 8705
# 1/1 [==============================] - 0s 41ms/step
# LOOP #8705:
# Batch 8705 shape: (500, 4)
# Predicted 8705 shape: (1, 4)
# All predicted values shape: (9206, 4)
# 8706
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8706:
# Batch 8706 shape: (500, 4)
# Predicted 8706 shape: (1, 4)
# All predicted values shape: (9207, 4)
# 8707
# 1/1 [==============================] - 0s 37ms/step
# LOOP #8707:
# Batch 8707 shape: (500, 4)
# Predicted 8707 shape: (1, 4)
# All predicted values shape: (9208, 4)
# 8708
# 1/1 [==============================] - 0s 29ms/step
# LOOP #8708:
# Batch 8708 shape: (500, 4)
# Predicted 8708 shape: (1, 4)
# All predicted values shape: (9209, 4)
# 8709
# 1/1 [==============================] - 0s 34ms/step
# LOOP #8709:
# Batch 8709 shape: (500, 4)
# Predicted 8709 shape: (1, 4)
# All predicted values shape: (9210, 4)
# 8710
# 1/1 [==============================] - 0s 32ms/step
# LOOP #8710:
# Batch 8710 shape: (500, 4)
# Predicted 8710 shape: (1, 4)
# All predicted values shape: (9211, 4)
# 8711
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8711:
# Batch 8711 shape: (500, 4)
# Predicted 8711 shape: (1, 4)
# All predicted values shape: (9212, 4)
# 8712
# 1/1 [==============================] - 0s 35ms/step
# LOOP #8712:
# Batch 8712 shape: (500, 4)
# Predicted 8712 shape: (1, 4)
# All predicted values shape: (9213, 4)
# 8713
# 1/1 [==============================] - 0s 33ms/step
# LOOP #8713:
# Batch 8713 shape: (500, 4)
# Predicted 8713 shape: (1, 4)
# All predicted values shape: (9214, 4)
# 8714
# 1/1 [==============================] - 0s 25ms/step
# LOOP #8714:
# Batch 8714 shape: (500, 4)
# Predicted 8714 shape: (1, 4)
# All predicted values shape: (9215, 4)
# 8715
# 1/1 [==============================] - 0s 33ms/step
# LOOP #8715:
# Batch 8715 shape: (500, 4)
# Predicted 8715 shape: (1, 4)
# All predicted values shape: (9216, 4)
# 8716
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8716:
# Batch 8716 shape: (500, 4)
# Predicted 8716 shape: (1, 4)
# All predicted values shape: (9217, 4)
# 8717
# 1/1 [==============================] - 0s 45ms/step
# LOOP #8717:
# Batch 8717 shape: (500, 4)
# Predicted 8717 shape: (1, 4)
# All predicted values shape: (9218, 4)
# 8718
# 1/1 [==============================] - 0s 29ms/step
# LOOP #8718:
# Batch 8718 shape: (500, 4)
# Predicted 8718 shape: (1, 4)
# All predicted values shape: (9219, 4)
# 8719
# 1/1 [==============================] - 0s 26ms/step
# LOOP #8719:
# Batch 8719 shape: (500, 4)
# Predicted 8719 shape: (1, 4)
# All predicted values shape: (9220, 4)
# 8720
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8720:
# Batch 8720 shape: (500, 4)
# Predicted 8720 shape: (1, 4)
# All predicted values shape: (9221, 4)
# 8721
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8721:
# Batch 8721 shape: (500, 4)
# Predicted 8721 shape: (1, 4)
# All predicted values shape: (9222, 4)
# 8722
# 1/1 [==============================] - 0s 29ms/step
# LOOP #8722:
# Batch 8722 shape: (500, 4)
# Predicted 8722 shape: (1, 4)
# All predicted values shape: (9223, 4)
# 8723
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8723:
# Batch 8723 shape: (500, 4)
# Predicted 8723 shape: (1, 4)
# All predicted values shape: (9224, 4)
# 8724
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8724:
# Batch 8724 shape: (500, 4)
# Predicted 8724 shape: (1, 4)
# All predicted values shape: (9225, 4)
# 8725
# 1/1 [==============================] - 0s 27ms/step
# LOOP #8725:
# Batch 8725 shape: (500, 4)
# Predicted 8725 shape: (1, 4)
# All predicted values shape: (9226, 4)
# 8726
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8726:
# Batch 8726 shape: (500, 4)
# Predicted 8726 shape: (1, 4)
# All predicted values shape: (9227, 4)
# 8727
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8727:
# Batch 8727 shape: (500, 4)
# Predicted 8727 shape: (1, 4)
# All predicted values shape: (9228, 4)
# 8728
# 1/1 [==============================] - 0s 39ms/step
# LOOP #8728:
# Batch 8728 shape: (500, 4)
# Predicted 8728 shape: (1, 4)
# All predicted values shape: (9229, 4)
# 8729
# 1/1 [==============================] - 0s 34ms/step
# LOOP #8729:
# Batch 8729 shape: (500, 4)
# Predicted 8729 shape: (1, 4)
# All predicted values shape: (9230, 4)
# 8730
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8730:
# Batch 8730 shape: (500, 4)
# Predicted 8730 shape: (1, 4)
# All predicted values shape: (9231, 4)
# 8731
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8731:
# Batch 8731 shape: (500, 4)
# Predicted 8731 shape: (1, 4)
# All predicted values shape: (9232, 4)
# 8732
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8732:
# Batch 8732 shape: (500, 4)
# Predicted 8732 shape: (1, 4)
# All predicted values shape: (9233, 4)
# 8733
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8733:
# Batch 8733 shape: (500, 4)
# Predicted 8733 shape: (1, 4)
# All predicted values shape: (9234, 4)
# 8734
# 1/1 [==============================] - 0s 33ms/step
# LOOP #8734:
# Batch 8734 shape: (500, 4)
# Predicted 8734 shape: (1, 4)
# All predicted values shape: (9235, 4)
# 8735
# 1/1 [==============================] - 0s 29ms/step
# LOOP #8735:
# Batch 8735 shape: (500, 4)
# Predicted 8735 shape: (1, 4)
# All predicted values shape: (9236, 4)
# 8736
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8736:
# Batch 8736 shape: (500, 4)
# Predicted 8736 shape: (1, 4)
# All predicted values shape: (9237, 4)
# 8737
# 1/1 [==============================] - 0s 35ms/step
# LOOP #8737:
# Batch 8737 shape: (500, 4)
# Predicted 8737 shape: (1, 4)
# All predicted values shape: (9238, 4)
# 8738
# 1/1 [==============================] - 0s 26ms/step
# LOOP #8738:
# Batch 8738 shape: (500, 4)
# Predicted 8738 shape: (1, 4)
# All predicted values shape: (9239, 4)
# 8739
# 1/1 [==============================] - 0s 29ms/step
# LOOP #8739:
# Batch 8739 shape: (500, 4)
# Predicted 8739 shape: (1, 4)
# All predicted values shape: (9240, 4)
# 8740
# 1/1 [==============================] - 0s 40ms/step
# LOOP #8740:
# Batch 8740 shape: (500, 4)
# Predicted 8740 shape: (1, 4)
# All predicted values shape: (9241, 4)
# 8741
# 1/1 [==============================] - 0s 33ms/step
# LOOP #8741:
# Batch 8741 shape: (500, 4)
# Predicted 8741 shape: (1, 4)
# All predicted values shape: (9242, 4)
# 8742
# 1/1 [==============================] - 0s 34ms/step
# LOOP #8742:
# Batch 8742 shape: (500, 4)
# Predicted 8742 shape: (1, 4)
# All predicted values shape: (9243, 4)
# 8743
# 1/1 [==============================] - 0s 29ms/step
# LOOP #8743:
# Batch 8743 shape: (500, 4)
# Predicted 8743 shape: (1, 4)
# All predicted values shape: (9244, 4)
# 8744
# 1/1 [==============================] - 0s 32ms/step
# LOOP #8744:
# Batch 8744 shape: (500, 4)
# Predicted 8744 shape: (1, 4)
# All predicted values shape: (9245, 4)
# 8745
# 1/1 [==============================] - 0s 28ms/step
# LOOP #8745:
# Batch 8745 shape: (500, 4)
# Predicted 8745 shape: (1, 4)
# All predicted values shape: (9246, 4)
# 8746
# 1/1 [==============================] - 0s 35ms/step
# LOOP #8746:
# Batch 8746 shape: (500, 4)
# Predicted 8746 shape: (1, 4)
# All predicted values shape: (9247, 4)
# 8747
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8747:
# Batch 8747 shape: (500, 4)
# Predicted 8747 shape: (1, 4)
# All predicted values shape: (9248, 4)
# 8748
# 1/1 [==============================] - 0s 33ms/step
# LOOP #8748:
# Batch 8748 shape: (500, 4)
# Predicted 8748 shape: (1, 4)
# All predicted values shape: (9249, 4)
# 8749
# 1/1 [==============================] - 0s 33ms/step
# LOOP #8749:
# Batch 8749 shape: (500, 4)
# Predicted 8749 shape: (1, 4)
# All predicted values shape: (9250, 4)
# 8750
# 1/1 [==============================] - 0s 34ms/step
# LOOP #8750:
# Batch 8750 shape: (500, 4)
# Predicted 8750 shape: (1, 4)
# All predicted values shape: (9251, 4)
# 8751
# 1/1 [==============================] - 0s 34ms/step
# LOOP #8751:
# Batch 8751 shape: (500, 4)
# Predicted 8751 shape: (1, 4)
# All predicted values shape: (9252, 4)
# 8752
# 1/1 [==============================] - 0s 33ms/step
# LOOP #8752:
# Batch 8752 shape: (500, 4)
# Predicted 8752 shape: (1, 4)
# All predicted values shape: (9253, 4)
# 8753
# 1/1 [==============================] - 0s 29ms/step
# LOOP #8753:
# Batch 8753 shape: (500, 4)
# Predicted 8753 shape: (1, 4)
# All predicted values shape: (9254, 4)
# 8754
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8754:
# Batch 8754 shape: (500, 4)
# Predicted 8754 shape: (1, 4)
# All predicted values shape: (9255, 4)
# 8755
# 1/1 [==============================] - 0s 25ms/step
# LOOP #8755:
# Batch 8755 shape: (500, 4)
# Predicted 8755 shape: (1, 4)
# All predicted values shape: (9256, 4)
# 8756
# 1/1 [==============================] - 0s 27ms/step
# LOOP #8756:
# Batch 8756 shape: (500, 4)
# Predicted 8756 shape: (1, 4)
# All predicted values shape: (9257, 4)
# 8757
# 1/1 [==============================] - 0s 37ms/step
# LOOP #8757:
# Batch 8757 shape: (500, 4)
# Predicted 8757 shape: (1, 4)
# All predicted values shape: (9258, 4)
# 8758
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8758:
# Batch 8758 shape: (500, 4)
# Predicted 8758 shape: (1, 4)
# All predicted values shape: (9259, 4)
# 8759
# 1/1 [==============================] - 0s 32ms/step
# LOOP #8759:
# Batch 8759 shape: (500, 4)
# Predicted 8759 shape: (1, 4)
# All predicted values shape: (9260, 4)
# 8760
# 1/1 [==============================] - 0s 27ms/step
# LOOP #8760:
# Batch 8760 shape: (500, 4)
# Predicted 8760 shape: (1, 4)
# All predicted values shape: (9261, 4)
# 8761
# 1/1 [==============================] - 0s 34ms/step
# LOOP #8761:
# Batch 8761 shape: (500, 4)
# Predicted 8761 shape: (1, 4)
# All predicted values shape: (9262, 4)
# 8762
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8762:
# Batch 8762 shape: (500, 4)
# Predicted 8762 shape: (1, 4)
# All predicted values shape: (9263, 4)
# 8763
# 1/1 [==============================] - 0s 32ms/step
# LOOP #8763:
# Batch 8763 shape: (500, 4)
# Predicted 8763 shape: (1, 4)
# All predicted values shape: (9264, 4)
# 8764
# 1/1 [==============================] - 0s 32ms/step
# LOOP #8764:
# Batch 8764 shape: (500, 4)
# Predicted 8764 shape: (1, 4)
# All predicted values shape: (9265, 4)
# 8765
# 1/1 [==============================] - 0s 26ms/step
# LOOP #8765:
# Batch 8765 shape: (500, 4)
# Predicted 8765 shape: (1, 4)
# All predicted values shape: (9266, 4)
# 8766
# 1/1 [==============================] - 0s 44ms/step
# LOOP #8766:
# Batch 8766 shape: (500, 4)
# Predicted 8766 shape: (1, 4)
# All predicted values shape: (9267, 4)
# 8767
# 1/1 [==============================] - 0s 34ms/step
# LOOP #8767:
# Batch 8767 shape: (500, 4)
# Predicted 8767 shape: (1, 4)
# All predicted values shape: (9268, 4)
# 8768
# 1/1 [==============================] - 0s 35ms/step
# LOOP #8768:
# Batch 8768 shape: (500, 4)
# Predicted 8768 shape: (1, 4)
# All predicted values shape: (9269, 4)
# 8769
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8769:
# Batch 8769 shape: (500, 4)
# Predicted 8769 shape: (1, 4)
# All predicted values shape: (9270, 4)
# 8770
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8770:
# Batch 8770 shape: (500, 4)
# Predicted 8770 shape: (1, 4)
# All predicted values shape: (9271, 4)
# 8771
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8771:
# Batch 8771 shape: (500, 4)
# Predicted 8771 shape: (1, 4)
# All predicted values shape: (9272, 4)
# 8772
# 1/1 [==============================] - 0s 29ms/step
# LOOP #8772:
# Batch 8772 shape: (500, 4)
# Predicted 8772 shape: (1, 4)
# All predicted values shape: (9273, 4)
# 8773
# 1/1 [==============================] - 0s 33ms/step
# LOOP #8773:
# Batch 8773 shape: (500, 4)
# Predicted 8773 shape: (1, 4)
# All predicted values shape: (9274, 4)
# 8774
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8774:
# Batch 8774 shape: (500, 4)
# Predicted 8774 shape: (1, 4)
# All predicted values shape: (9275, 4)
# 8775
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8775:
# Batch 8775 shape: (500, 4)
# Predicted 8775 shape: (1, 4)
# All predicted values shape: (9276, 4)
# 8776
# 1/1 [==============================] - 0s 32ms/step
# LOOP #8776:
# Batch 8776 shape: (500, 4)
# Predicted 8776 shape: (1, 4)
# All predicted values shape: (9277, 4)
# 8777
# 1/1 [==============================] - 0s 27ms/step
# LOOP #8777:
# Batch 8777 shape: (500, 4)
# Predicted 8777 shape: (1, 4)
# All predicted values shape: (9278, 4)
# 8778
# 1/1 [==============================] - 0s 36ms/step
# LOOP #8778:
# Batch 8778 shape: (500, 4)
# Predicted 8778 shape: (1, 4)
# All predicted values shape: (9279, 4)
# 8779
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8779:
# Batch 8779 shape: (500, 4)
# Predicted 8779 shape: (1, 4)
# All predicted values shape: (9280, 4)
# 8780
# 1/1 [==============================] - 0s 32ms/step
# LOOP #8780:
# Batch 8780 shape: (500, 4)
# Predicted 8780 shape: (1, 4)
# All predicted values shape: (9281, 4)
# 8781
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8781:
# Batch 8781 shape: (500, 4)
# Predicted 8781 shape: (1, 4)
# All predicted values shape: (9282, 4)
# 8782
# 1/1 [==============================] - 0s 32ms/step
# LOOP #8782:
# Batch 8782 shape: (500, 4)
# Predicted 8782 shape: (1, 4)
# All predicted values shape: (9283, 4)
# 8783
# 1/1 [==============================] - 0s 34ms/step
# LOOP #8783:
# Batch 8783 shape: (500, 4)
# Predicted 8783 shape: (1, 4)
# All predicted values shape: (9284, 4)
# 8784
# 1/1 [==============================] - 0s 32ms/step
# LOOP #8784:
# Batch 8784 shape: (500, 4)
# Predicted 8784 shape: (1, 4)
# All predicted values shape: (9285, 4)
# 8785
# 1/1 [==============================] - 0s 26ms/step
# LOOP #8785:
# Batch 8785 shape: (500, 4)
# Predicted 8785 shape: (1, 4)
# All predicted values shape: (9286, 4)
# 8786
# 1/1 [==============================] - 0s 39ms/step
# LOOP #8786:
# Batch 8786 shape: (500, 4)
# Predicted 8786 shape: (1, 4)
# All predicted values shape: (9287, 4)
# 8787
# 1/1 [==============================] - 0s 34ms/step
# LOOP #8787:
# Batch 8787 shape: (500, 4)
# Predicted 8787 shape: (1, 4)
# All predicted values shape: (9288, 4)
# 8788
# 1/1 [==============================] - 0s 33ms/step
# LOOP #8788:
# Batch 8788 shape: (500, 4)
# Predicted 8788 shape: (1, 4)
# All predicted values shape: (9289, 4)
# 8789
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8789:
# Batch 8789 shape: (500, 4)
# Predicted 8789 shape: (1, 4)
# All predicted values shape: (9290, 4)
# 8790
# 1/1 [==============================] - 0s 29ms/step
# LOOP #8790:
# Batch 8790 shape: (500, 4)
# Predicted 8790 shape: (1, 4)
# All predicted values shape: (9291, 4)
# 8791
# 1/1 [==============================] - 0s 40ms/step
# LOOP #8791:
# Batch 8791 shape: (500, 4)
# Predicted 8791 shape: (1, 4)
# All predicted values shape: (9292, 4)
# 8792
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8792:
# Batch 8792 shape: (500, 4)
# Predicted 8792 shape: (1, 4)
# All predicted values shape: (9293, 4)
# 8793
# 1/1 [==============================] - 0s 33ms/step
# LOOP #8793:
# Batch 8793 shape: (500, 4)
# Predicted 8793 shape: (1, 4)
# All predicted values shape: (9294, 4)
# 8794
# 1/1 [==============================] - 0s 28ms/step
# LOOP #8794:
# Batch 8794 shape: (500, 4)
# Predicted 8794 shape: (1, 4)
# All predicted values shape: (9295, 4)
# 8795
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8795:
# Batch 8795 shape: (500, 4)
# Predicted 8795 shape: (1, 4)
# All predicted values shape: (9296, 4)
# 8796
# 1/1 [==============================] - 0s 35ms/step
# LOOP #8796:
# Batch 8796 shape: (500, 4)
# Predicted 8796 shape: (1, 4)
# All predicted values shape: (9297, 4)
# 8797
# 1/1 [==============================] - 0s 40ms/step
# LOOP #8797:
# Batch 8797 shape: (500, 4)
# Predicted 8797 shape: (1, 4)
# All predicted values shape: (9298, 4)
# 8798
# 1/1 [==============================] - 0s 36ms/step
# LOOP #8798:
# Batch 8798 shape: (500, 4)
# Predicted 8798 shape: (1, 4)
# All predicted values shape: (9299, 4)
# 8799
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8799:
# Batch 8799 shape: (500, 4)
# Predicted 8799 shape: (1, 4)
# All predicted values shape: (9300, 4)
# 8800
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8800:
# Batch 8800 shape: (500, 4)
# Predicted 8800 shape: (1, 4)
# All predicted values shape: (9301, 4)
# 8801
# 1/1 [==============================] - 0s 28ms/step
# LOOP #8801:
# Batch 8801 shape: (500, 4)
# Predicted 8801 shape: (1, 4)
# All predicted values shape: (9302, 4)
# 8802
# 1/1 [==============================] - 0s 29ms/step
# LOOP #8802:
# Batch 8802 shape: (500, 4)
# Predicted 8802 shape: (1, 4)
# All predicted values shape: (9303, 4)
# 8803
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8803:
# Batch 8803 shape: (500, 4)
# Predicted 8803 shape: (1, 4)
# All predicted values shape: (9304, 4)
# 8804
# 1/1 [==============================] - 0s 33ms/step
# LOOP #8804:
# Batch 8804 shape: (500, 4)
# Predicted 8804 shape: (1, 4)
# All predicted values shape: (9305, 4)
# 8805
# 1/1 [==============================] - 0s 26ms/step
# LOOP #8805:
# Batch 8805 shape: (500, 4)
# Predicted 8805 shape: (1, 4)
# All predicted values shape: (9306, 4)
# 8806
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8806:
# Batch 8806 shape: (500, 4)
# Predicted 8806 shape: (1, 4)
# All predicted values shape: (9307, 4)
# 8807
# 1/1 [==============================] - 0s 32ms/step
# LOOP #8807:
# Batch 8807 shape: (500, 4)
# Predicted 8807 shape: (1, 4)
# All predicted values shape: (9308, 4)
# 8808
# 1/1 [==============================] - 0s 33ms/step
# LOOP #8808:
# Batch 8808 shape: (500, 4)
# Predicted 8808 shape: (1, 4)
# All predicted values shape: (9309, 4)
# 8809
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8809:
# Batch 8809 shape: (500, 4)
# Predicted 8809 shape: (1, 4)
# All predicted values shape: (9310, 4)
# 8810
# 1/1 [==============================] - 0s 33ms/step
# LOOP #8810:
# Batch 8810 shape: (500, 4)
# Predicted 8810 shape: (1, 4)
# All predicted values shape: (9311, 4)
# 8811
# 1/1 [==============================] - 0s 27ms/step
# LOOP #8811:
# Batch 8811 shape: (500, 4)
# Predicted 8811 shape: (1, 4)
# All predicted values shape: (9312, 4)
# 8812
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8812:
# Batch 8812 shape: (500, 4)
# Predicted 8812 shape: (1, 4)
# All predicted values shape: (9313, 4)
# 8813
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8813:
# Batch 8813 shape: (500, 4)
# Predicted 8813 shape: (1, 4)
# All predicted values shape: (9314, 4)
# 8814
# 1/1 [==============================] - 0s 35ms/step
# LOOP #8814:
# Batch 8814 shape: (500, 4)
# Predicted 8814 shape: (1, 4)
# All predicted values shape: (9315, 4)
# 8815
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8815:
# Batch 8815 shape: (500, 4)
# Predicted 8815 shape: (1, 4)
# All predicted values shape: (9316, 4)
# 8816
# 1/1 [==============================] - 0s 28ms/step
# LOOP #8816:
# Batch 8816 shape: (500, 4)
# Predicted 8816 shape: (1, 4)
# All predicted values shape: (9317, 4)
# 8817
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8817:
# Batch 8817 shape: (500, 4)
# Predicted 8817 shape: (1, 4)
# All predicted values shape: (9318, 4)
# 8818
# 1/1 [==============================] - 0s 25ms/step
# LOOP #8818:
# Batch 8818 shape: (500, 4)
# Predicted 8818 shape: (1, 4)
# All predicted values shape: (9319, 4)
# 8819
# 1/1 [==============================] - 0s 29ms/step
# LOOP #8819:
# Batch 8819 shape: (500, 4)
# Predicted 8819 shape: (1, 4)
# All predicted values shape: (9320, 4)
# 8820
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8820:
# Batch 8820 shape: (500, 4)
# Predicted 8820 shape: (1, 4)
# All predicted values shape: (9321, 4)
# 8821
# 1/1 [==============================] - 0s 32ms/step
# LOOP #8821:
# Batch 8821 shape: (500, 4)
# Predicted 8821 shape: (1, 4)
# All predicted values shape: (9322, 4)
# 8822
# 1/1 [==============================] - 0s 34ms/step
# LOOP #8822:
# Batch 8822 shape: (500, 4)
# Predicted 8822 shape: (1, 4)
# All predicted values shape: (9323, 4)
# 8823
# 1/1 [==============================] - 0s 34ms/step
# LOOP #8823:
# Batch 8823 shape: (500, 4)
# Predicted 8823 shape: (1, 4)
# All predicted values shape: (9324, 4)
# 8824
# 1/1 [==============================] - 0s 36ms/step
# LOOP #8824:
# Batch 8824 shape: (500, 4)
# Predicted 8824 shape: (1, 4)
# All predicted values shape: (9325, 4)
# 8825
# 1/1 [==============================] - 0s 35ms/step
# LOOP #8825:
# Batch 8825 shape: (500, 4)
# Predicted 8825 shape: (1, 4)
# All predicted values shape: (9326, 4)
# 8826
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8826:
# Batch 8826 shape: (500, 4)
# Predicted 8826 shape: (1, 4)
# All predicted values shape: (9327, 4)
# 8827
# 1/1 [==============================] - 0s 32ms/step
# LOOP #8827:
# Batch 8827 shape: (500, 4)
# Predicted 8827 shape: (1, 4)
# All predicted values shape: (9328, 4)
# 8828
# 1/1 [==============================] - 0s 29ms/step
# LOOP #8828:
# Batch 8828 shape: (500, 4)
# Predicted 8828 shape: (1, 4)
# All predicted values shape: (9329, 4)
# 8829
# 1/1 [==============================] - 0s 34ms/step
# LOOP #8829:
# Batch 8829 shape: (500, 4)
# Predicted 8829 shape: (1, 4)
# All predicted values shape: (9330, 4)
# 8830
# 1/1 [==============================] - 0s 29ms/step
# LOOP #8830:
# Batch 8830 shape: (500, 4)
# Predicted 8830 shape: (1, 4)
# All predicted values shape: (9331, 4)
# 8831
# 1/1 [==============================] - 0s 32ms/step
# LOOP #8831:
# Batch 8831 shape: (500, 4)
# Predicted 8831 shape: (1, 4)
# All predicted values shape: (9332, 4)
# 8832
# 1/1 [==============================] - 0s 29ms/step
# LOOP #8832:
# Batch 8832 shape: (500, 4)
# Predicted 8832 shape: (1, 4)
# All predicted values shape: (9333, 4)
# 8833
# 1/1 [==============================] - 0s 40ms/step
# LOOP #8833:
# Batch 8833 shape: (500, 4)
# Predicted 8833 shape: (1, 4)
# All predicted values shape: (9334, 4)
# 8834
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8834:
# Batch 8834 shape: (500, 4)
# Predicted 8834 shape: (1, 4)
# All predicted values shape: (9335, 4)
# 8835
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8835:
# Batch 8835 shape: (500, 4)
# Predicted 8835 shape: (1, 4)
# All predicted values shape: (9336, 4)
# 8836
# 1/1 [==============================] - 0s 27ms/step
# LOOP #8836:
# Batch 8836 shape: (500, 4)
# Predicted 8836 shape: (1, 4)
# All predicted values shape: (9337, 4)
# 8837
# 1/1 [==============================] - 0s 27ms/step
# LOOP #8837:
# Batch 8837 shape: (500, 4)
# Predicted 8837 shape: (1, 4)
# All predicted values shape: (9338, 4)
# 8838
# 1/1 [==============================] - 0s 29ms/step
# LOOP #8838:
# Batch 8838 shape: (500, 4)
# Predicted 8838 shape: (1, 4)
# All predicted values shape: (9339, 4)
# 8839
# 1/1 [==============================] - 0s 33ms/step
# LOOP #8839:
# Batch 8839 shape: (500, 4)
# Predicted 8839 shape: (1, 4)
# All predicted values shape: (9340, 4)
# 8840
# 1/1 [==============================] - 0s 34ms/step
# LOOP #8840:
# Batch 8840 shape: (500, 4)
# Predicted 8840 shape: (1, 4)
# All predicted values shape: (9341, 4)
# 8841
# 1/1 [==============================] - 0s 32ms/step
# LOOP #8841:
# Batch 8841 shape: (500, 4)
# Predicted 8841 shape: (1, 4)
# All predicted values shape: (9342, 4)
# 8842
# 1/1 [==============================] - 0s 36ms/step
# LOOP #8842:
# Batch 8842 shape: (500, 4)
# Predicted 8842 shape: (1, 4)
# All predicted values shape: (9343, 4)
# 8843
# 1/1 [==============================] - 0s 34ms/step
# LOOP #8843:
# Batch 8843 shape: (500, 4)
# Predicted 8843 shape: (1, 4)
# All predicted values shape: (9344, 4)
# 8844
# 1/1 [==============================] - 0s 34ms/step
# LOOP #8844:
# Batch 8844 shape: (500, 4)
# Predicted 8844 shape: (1, 4)
# All predicted values shape: (9345, 4)
# 8845
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8845:
# Batch 8845 shape: (500, 4)
# Predicted 8845 shape: (1, 4)
# All predicted values shape: (9346, 4)
# 8846
# 1/1 [==============================] - 0s 26ms/step
# LOOP #8846:
# Batch 8846 shape: (500, 4)
# Predicted 8846 shape: (1, 4)
# All predicted values shape: (9347, 4)
# 8847
# 1/1 [==============================] - 0s 36ms/step
# LOOP #8847:
# Batch 8847 shape: (500, 4)
# Predicted 8847 shape: (1, 4)
# All predicted values shape: (9348, 4)
# 8848
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8848:
# Batch 8848 shape: (500, 4)
# Predicted 8848 shape: (1, 4)
# All predicted values shape: (9349, 4)
# 8849
# 1/1 [==============================] - 0s 34ms/step
# LOOP #8849:
# Batch 8849 shape: (500, 4)
# Predicted 8849 shape: (1, 4)
# All predicted values shape: (9350, 4)
# 8850
# 1/1 [==============================] - 0s 34ms/step
# LOOP #8850:
# Batch 8850 shape: (500, 4)
# Predicted 8850 shape: (1, 4)
# All predicted values shape: (9351, 4)
# 8851
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8851:
# Batch 8851 shape: (500, 4)
# Predicted 8851 shape: (1, 4)
# All predicted values shape: (9352, 4)
# 8852
# 1/1 [==============================] - 0s 28ms/step
# LOOP #8852:
# Batch 8852 shape: (500, 4)
# Predicted 8852 shape: (1, 4)
# All predicted values shape: (9353, 4)
# 8853
# 1/1 [==============================] - 0s 38ms/step
# LOOP #8853:
# Batch 8853 shape: (500, 4)
# Predicted 8853 shape: (1, 4)
# All predicted values shape: (9354, 4)
# 8854
# 1/1 [==============================] - 0s 37ms/step
# LOOP #8854:
# Batch 8854 shape: (500, 4)
# Predicted 8854 shape: (1, 4)
# All predicted values shape: (9355, 4)
# 8855
# 1/1 [==============================] - 0s 26ms/step
# LOOP #8855:
# Batch 8855 shape: (500, 4)
# Predicted 8855 shape: (1, 4)
# All predicted values shape: (9356, 4)
# 8856
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8856:
# Batch 8856 shape: (500, 4)
# Predicted 8856 shape: (1, 4)
# All predicted values shape: (9357, 4)
# 8857
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8857:
# Batch 8857 shape: (500, 4)
# Predicted 8857 shape: (1, 4)
# All predicted values shape: (9358, 4)
# 8858
# 1/1 [==============================] - 0s 26ms/step
# LOOP #8858:
# Batch 8858 shape: (500, 4)
# Predicted 8858 shape: (1, 4)
# All predicted values shape: (9359, 4)
# 8859
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8859:
# Batch 8859 shape: (500, 4)
# Predicted 8859 shape: (1, 4)
# All predicted values shape: (9360, 4)
# 8860
# 1/1 [==============================] - 0s 38ms/step
# LOOP #8860:
# Batch 8860 shape: (500, 4)
# Predicted 8860 shape: (1, 4)
# All predicted values shape: (9361, 4)
# 8861
# 1/1 [==============================] - 0s 35ms/step
# LOOP #8861:
# Batch 8861 shape: (500, 4)
# Predicted 8861 shape: (1, 4)
# All predicted values shape: (9362, 4)
# 8862
# 1/1 [==============================] - 0s 32ms/step
# LOOP #8862:
# Batch 8862 shape: (500, 4)
# Predicted 8862 shape: (1, 4)
# All predicted values shape: (9363, 4)
# 8863
# 1/1 [==============================] - 0s 28ms/step
# LOOP #8863:
# Batch 8863 shape: (500, 4)
# Predicted 8863 shape: (1, 4)
# All predicted values shape: (9364, 4)
# 8864
# 1/1 [==============================] - 0s 34ms/step
# LOOP #8864:
# Batch 8864 shape: (500, 4)
# Predicted 8864 shape: (1, 4)
# All predicted values shape: (9365, 4)
# 8865
# 1/1 [==============================] - 0s 33ms/step
# LOOP #8865:
# Batch 8865 shape: (500, 4)
# Predicted 8865 shape: (1, 4)
# All predicted values shape: (9366, 4)
# 8866
# 1/1 [==============================] - 0s 29ms/step
# LOOP #8866:
# Batch 8866 shape: (500, 4)
# Predicted 8866 shape: (1, 4)
# All predicted values shape: (9367, 4)
# 8867
# 1/1 [==============================] - 0s 27ms/step
# LOOP #8867:
# Batch 8867 shape: (500, 4)
# Predicted 8867 shape: (1, 4)
# All predicted values shape: (9368, 4)
# 8868
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8868:
# Batch 8868 shape: (500, 4)
# Predicted 8868 shape: (1, 4)
# All predicted values shape: (9369, 4)
# 8869
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8869:
# Batch 8869 shape: (500, 4)
# Predicted 8869 shape: (1, 4)
# All predicted values shape: (9370, 4)
# 8870
# 1/1 [==============================] - 0s 32ms/step
# LOOP #8870:
# Batch 8870 shape: (500, 4)
# Predicted 8870 shape: (1, 4)
# All predicted values shape: (9371, 4)
# 8871
# 1/1 [==============================] - 0s 35ms/step
# LOOP #8871:
# Batch 8871 shape: (500, 4)
# Predicted 8871 shape: (1, 4)
# All predicted values shape: (9372, 4)
# 8872
# 1/1 [==============================] - 0s 29ms/step
# LOOP #8872:
# Batch 8872 shape: (500, 4)
# Predicted 8872 shape: (1, 4)
# All predicted values shape: (9373, 4)
# 8873
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8873:
# Batch 8873 shape: (500, 4)
# Predicted 8873 shape: (1, 4)
# All predicted values shape: (9374, 4)
# 8874
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8874:
# Batch 8874 shape: (500, 4)
# Predicted 8874 shape: (1, 4)
# All predicted values shape: (9375, 4)
# 8875
# 1/1 [==============================] - 0s 40ms/step
# LOOP #8875:
# Batch 8875 shape: (500, 4)
# Predicted 8875 shape: (1, 4)
# All predicted values shape: (9376, 4)
# 8876
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8876:
# Batch 8876 shape: (500, 4)
# Predicted 8876 shape: (1, 4)
# All predicted values shape: (9377, 4)
# 8877
# 1/1 [==============================] - 0s 33ms/step
# LOOP #8877:
# Batch 8877 shape: (500, 4)
# Predicted 8877 shape: (1, 4)
# All predicted values shape: (9378, 4)
# 8878
# 1/1 [==============================] - 0s 35ms/step
# LOOP #8878:
# Batch 8878 shape: (500, 4)
# Predicted 8878 shape: (1, 4)
# All predicted values shape: (9379, 4)
# 8879
# 1/1 [==============================] - 0s 28ms/step
# LOOP #8879:
# Batch 8879 shape: (500, 4)
# Predicted 8879 shape: (1, 4)
# All predicted values shape: (9380, 4)
# 8880
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8880:
# Batch 8880 shape: (500, 4)
# Predicted 8880 shape: (1, 4)
# All predicted values shape: (9381, 4)
# 8881
# 1/1 [==============================] - 0s 27ms/step
# LOOP #8881:
# Batch 8881 shape: (500, 4)
# Predicted 8881 shape: (1, 4)
# All predicted values shape: (9382, 4)
# 8882
# 1/1 [==============================] - 0s 29ms/step
# LOOP #8882:
# Batch 8882 shape: (500, 4)
# Predicted 8882 shape: (1, 4)
# All predicted values shape: (9383, 4)
# 8883
# 1/1 [==============================] - 0s 29ms/step
# LOOP #8883:
# Batch 8883 shape: (500, 4)
# Predicted 8883 shape: (1, 4)
# All predicted values shape: (9384, 4)
# 8884
# 1/1 [==============================] - 0s 35ms/step
# LOOP #8884:
# Batch 8884 shape: (500, 4)
# Predicted 8884 shape: (1, 4)
# All predicted values shape: (9385, 4)
# 8885
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8885:
# Batch 8885 shape: (500, 4)
# Predicted 8885 shape: (1, 4)
# All predicted values shape: (9386, 4)
# 8886
# 1/1 [==============================] - 0s 33ms/step
# LOOP #8886:
# Batch 8886 shape: (500, 4)
# Predicted 8886 shape: (1, 4)
# All predicted values shape: (9387, 4)
# 8887
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8887:
# Batch 8887 shape: (500, 4)
# Predicted 8887 shape: (1, 4)
# All predicted values shape: (9388, 4)
# 8888
# 1/1 [==============================] - 0s 32ms/step
# LOOP #8888:
# Batch 8888 shape: (500, 4)
# Predicted 8888 shape: (1, 4)
# All predicted values shape: (9389, 4)
# 8889
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8889:
# Batch 8889 shape: (500, 4)
# Predicted 8889 shape: (1, 4)
# All predicted values shape: (9390, 4)
# 8890
# 1/1 [==============================] - 0s 32ms/step
# LOOP #8890:
# Batch 8890 shape: (500, 4)
# Predicted 8890 shape: (1, 4)
# All predicted values shape: (9391, 4)
# 8891
# 1/1 [==============================] - 0s 25ms/step
# LOOP #8891:
# Batch 8891 shape: (500, 4)
# Predicted 8891 shape: (1, 4)
# All predicted values shape: (9392, 4)
# 8892
# 1/1 [==============================] - 0s 34ms/step
# LOOP #8892:
# Batch 8892 shape: (500, 4)
# Predicted 8892 shape: (1, 4)
# All predicted values shape: (9393, 4)
# 8893
# 1/1 [==============================] - 0s 26ms/step
# LOOP #8893:
# Batch 8893 shape: (500, 4)
# Predicted 8893 shape: (1, 4)
# All predicted values shape: (9394, 4)
# 8894
# 1/1 [==============================] - 0s 33ms/step
# LOOP #8894:
# Batch 8894 shape: (500, 4)
# Predicted 8894 shape: (1, 4)
# All predicted values shape: (9395, 4)
# 8895
# 1/1 [==============================] - 0s 35ms/step
# LOOP #8895:
# Batch 8895 shape: (500, 4)
# Predicted 8895 shape: (1, 4)
# All predicted values shape: (9396, 4)
# 8896
# 1/1 [==============================] - 0s 33ms/step
# LOOP #8896:
# Batch 8896 shape: (500, 4)
# Predicted 8896 shape: (1, 4)
# All predicted values shape: (9397, 4)
# 8897
# 1/1 [==============================] - 0s 27ms/step
# LOOP #8897:
# Batch 8897 shape: (500, 4)
# Predicted 8897 shape: (1, 4)
# All predicted values shape: (9398, 4)
# 8898
# 1/1 [==============================] - 0s 33ms/step
# LOOP #8898:
# Batch 8898 shape: (500, 4)
# Predicted 8898 shape: (1, 4)
# All predicted values shape: (9399, 4)
# 8899
# 1/1 [==============================] - 0s 36ms/step
# LOOP #8899:
# Batch 8899 shape: (500, 4)
# Predicted 8899 shape: (1, 4)
# All predicted values shape: (9400, 4)
# 8900
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8900:
# Batch 8900 shape: (500, 4)
# Predicted 8900 shape: (1, 4)
# All predicted values shape: (9401, 4)
# 8901
# 1/1 [==============================] - 0s 38ms/step
# LOOP #8901:
# Batch 8901 shape: (500, 4)
# Predicted 8901 shape: (1, 4)
# All predicted values shape: (9402, 4)
# 8902
# 1/1 [==============================] - 0s 42ms/step
# LOOP #8902:
# Batch 8902 shape: (500, 4)
# Predicted 8902 shape: (1, 4)
# All predicted values shape: (9403, 4)
# 8903
# 1/1 [==============================] - 0s 36ms/step
# LOOP #8903:
# Batch 8903 shape: (500, 4)
# Predicted 8903 shape: (1, 4)
# All predicted values shape: (9404, 4)
# 8904
# 1/1 [==============================] - 0s 25ms/step
# LOOP #8904:
# Batch 8904 shape: (500, 4)
# Predicted 8904 shape: (1, 4)
# All predicted values shape: (9405, 4)
# 8905
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8905:
# Batch 8905 shape: (500, 4)
# Predicted 8905 shape: (1, 4)
# All predicted values shape: (9406, 4)
# 8906
# 1/1 [==============================] - 0s 46ms/step
# LOOP #8906:
# Batch 8906 shape: (500, 4)
# Predicted 8906 shape: (1, 4)
# All predicted values shape: (9407, 4)
# 8907
# 1/1 [==============================] - 0s 28ms/step
# LOOP #8907:
# Batch 8907 shape: (500, 4)
# Predicted 8907 shape: (1, 4)
# All predicted values shape: (9408, 4)
# 8908
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8908:
# Batch 8908 shape: (500, 4)
# Predicted 8908 shape: (1, 4)
# All predicted values shape: (9409, 4)
# 8909
# 1/1 [==============================] - 0s 35ms/step
# LOOP #8909:
# Batch 8909 shape: (500, 4)
# Predicted 8909 shape: (1, 4)
# All predicted values shape: (9410, 4)
# 8910
# 1/1 [==============================] - 0s 33ms/step
# LOOP #8910:
# Batch 8910 shape: (500, 4)
# Predicted 8910 shape: (1, 4)
# All predicted values shape: (9411, 4)
# 8911
# 1/1 [==============================] - 0s 34ms/step
# LOOP #8911:
# Batch 8911 shape: (500, 4)
# Predicted 8911 shape: (1, 4)
# All predicted values shape: (9412, 4)
# 8912
# 1/1 [==============================] - 0s 37ms/step
# LOOP #8912:
# Batch 8912 shape: (500, 4)
# Predicted 8912 shape: (1, 4)
# All predicted values shape: (9413, 4)
# 8913
# 1/1 [==============================] - 0s 34ms/step
# LOOP #8913:
# Batch 8913 shape: (500, 4)
# Predicted 8913 shape: (1, 4)
# All predicted values shape: (9414, 4)
# 8914
# 1/1 [==============================] - 0s 28ms/step
# LOOP #8914:
# Batch 8914 shape: (500, 4)
# Predicted 8914 shape: (1, 4)
# All predicted values shape: (9415, 4)
# 8915
# 1/1 [==============================] - 0s 36ms/step
# LOOP #8915:
# Batch 8915 shape: (500, 4)
# Predicted 8915 shape: (1, 4)
# All predicted values shape: (9416, 4)
# 8916
# 1/1 [==============================] - 0s 32ms/step
# LOOP #8916:
# Batch 8916 shape: (500, 4)
# Predicted 8916 shape: (1, 4)
# All predicted values shape: (9417, 4)
# 8917
# 1/1 [==============================] - 0s 27ms/step
# LOOP #8917:
# Batch 8917 shape: (500, 4)
# Predicted 8917 shape: (1, 4)
# All predicted values shape: (9418, 4)
# 8918
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8918:
# Batch 8918 shape: (500, 4)
# Predicted 8918 shape: (1, 4)
# All predicted values shape: (9419, 4)
# 8919
# 1/1 [==============================] - 0s 34ms/step
# LOOP #8919:
# Batch 8919 shape: (500, 4)
# Predicted 8919 shape: (1, 4)
# All predicted values shape: (9420, 4)
# 8920
# 1/1 [==============================] - 0s 33ms/step
# LOOP #8920:
# Batch 8920 shape: (500, 4)
# Predicted 8920 shape: (1, 4)
# All predicted values shape: (9421, 4)
# 8921
# 1/1 [==============================] - 0s 29ms/step
# LOOP #8921:
# Batch 8921 shape: (500, 4)
# Predicted 8921 shape: (1, 4)
# All predicted values shape: (9422, 4)
# 8922
# 1/1 [==============================] - 0s 32ms/step
# LOOP #8922:
# Batch 8922 shape: (500, 4)
# Predicted 8922 shape: (1, 4)
# All predicted values shape: (9423, 4)
# 8923
# 1/1 [==============================] - 0s 35ms/step
# LOOP #8923:
# Batch 8923 shape: (500, 4)
# Predicted 8923 shape: (1, 4)
# All predicted values shape: (9424, 4)
# 8924
# 1/1 [==============================] - 0s 32ms/step
# LOOP #8924:
# Batch 8924 shape: (500, 4)
# Predicted 8924 shape: (1, 4)
# All predicted values shape: (9425, 4)
# 8925
# 1/1 [==============================] - 0s 27ms/step
# LOOP #8925:
# Batch 8925 shape: (500, 4)
# Predicted 8925 shape: (1, 4)
# All predicted values shape: (9426, 4)
# 8926
# 1/1 [==============================] - 0s 32ms/step
# LOOP #8926:
# Batch 8926 shape: (500, 4)
# Predicted 8926 shape: (1, 4)
# All predicted values shape: (9427, 4)
# 8927
# 1/1 [==============================] - 0s 26ms/step
# LOOP #8927:
# Batch 8927 shape: (500, 4)
# Predicted 8927 shape: (1, 4)
# All predicted values shape: (9428, 4)
# 8928
# 1/1 [==============================] - 0s 36ms/step
# LOOP #8928:
# Batch 8928 shape: (500, 4)
# Predicted 8928 shape: (1, 4)
# All predicted values shape: (9429, 4)
# 8929
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8929:
# Batch 8929 shape: (500, 4)
# Predicted 8929 shape: (1, 4)
# All predicted values shape: (9430, 4)
# 8930
# 1/1 [==============================] - 0s 33ms/step
# LOOP #8930:
# Batch 8930 shape: (500, 4)
# Predicted 8930 shape: (1, 4)
# All predicted values shape: (9431, 4)
# 8931
# 1/1 [==============================] - 0s 35ms/step
# LOOP #8931:
# Batch 8931 shape: (500, 4)
# Predicted 8931 shape: (1, 4)
# All predicted values shape: (9432, 4)
# 8932
# 1/1 [==============================] - 0s 31ms/step
# LOOP #8932:
# Batch 8932 shape: (500, 4)
# Predicted 8932 shape: (1, 4)
# All predicted values shape: (9433, 4)
# 8933
# 1/1 [==============================] - 0s 33ms/step
# LOOP #8933:
# Batch 8933 shape: (500, 4)
# Predicted 8933 shape: (1, 4)
# All predicted values shape: (9434, 4)
# 8934
# 1/1 [==============================] - 0s 27ms/step
# LOOP #8934:
# Batch 8934 shape: (500, 4)
# Predicted 8934 shape: (1, 4)
# All predicted values shape: (9435, 4)
# 8935
# 1/1 [==============================] - 0s 35ms/step
# LOOP #8935:
# Batch 8935 shape: (500, 4)
# Predicted 8935 shape: (1, 4)
# All predicted values shape: (9436, 4)
# 8936
# 1/1 [==============================] - 0s 30ms/step
# LOOP #8936:
# Batch 8936 shape: (500, 4)
# Predicted 8936 shape: (1, 4)
# All predicted values shape: (9437, 4)
# 8937
# 1/1 [==============================] - 0s 35ms/step
# LOOP #8937:
# Batch 8937 shape: (500, 4)
# Predicted 8937 shape: (1, 4)
# All predicted values shape: (9438, 4)
# 8938
# 1/1 [==============================] - 0s 28ms/step
# LOOP #8938:
# Batch 8938 shape: (500, 4)
# ...
# 9380
# 1/1 [==============================] - 0s 26ms/step
# LOOP #9380:
# Batch 9380 shape: (500, 4)
# Predicted 9380 shape: (1, 4)
# All predicted values shape: (9881, 4)
# 9381
# 1/1 [==============================] - 0s 30ms/step
# LOOP #9381:
# Batch 9381 shape: (500, 4)
# Predicted 9381 shape: (1, 4)
# All predicted values shape: (9882, 4)
# 9382
# 1/1 [==============================] - 0s 32ms/step
# LOOP #9382:
# Batch 9382 shape: (500, 4)
# Predicted 9382 shape: (1, 4)
# All predicted values shape: (9883, 4)
# 9383
# 1/1 [==============================] - 0s 35ms/step
# LOOP #9383:
# Batch 9383 shape: (500, 4)
# Predicted 9383 shape: (1, 4)
# All predicted values shape: (9884, 4)
# 9384
# 1/1 [==============================] - 0s 34ms/step
# LOOP #9384:
# Batch 9384 shape: (500, 4)
# Predicted 9384 shape: (1, 4)
# All predicted values shape: (9885, 4)
# 9385
# 1/1 [==============================] - 0s 32ms/step
# LOOP #9385:
# Batch 9385 shape: (500, 4)
# Predicted 9385 shape: (1, 4)
# All predicted values shape: (9886, 4)
# 9386
# 1/1 [==============================] - 0s 33ms/step
# LOOP #9386:
# Batch 9386 shape: (500, 4)
# Predicted 9386 shape: (1, 4)
# All predicted values shape: (9887, 4)
# 9387
# 1/1 [==============================] - 0s 28ms/step
# LOOP #9387:
# Batch 9387 shape: (500, 4)
# Predicted 9387 shape: (1, 4)
# All predicted values shape: (9888, 4)
# 9388
# 1/1 [==============================] - 0s 34ms/step
# LOOP #9388:
# Batch 9388 shape: (500, 4)
# Predicted 9388 shape: (1, 4)
# All predicted values shape: (9889, 4)
# 9389
# 1/1 [==============================] - 0s 32ms/step
# LOOP #9389:
# Batch 9389 shape: (500, 4)
# Predicted 9389 shape: (1, 4)
# All predicted values shape: (9890, 4)
# 9390
# 1/1 [==============================] - 0s 28ms/step
# LOOP #9390:
# Batch 9390 shape: (500, 4)
# Predicted 9390 shape: (1, 4)
# All predicted values shape: (9891, 4)
# 9391
# 1/1 [==============================] - 0s 31ms/step
# LOOP #9391:
# Batch 9391 shape: (500, 4)
# Predicted 9391 shape: (1, 4)
# All predicted values shape: (9892, 4)
# 9392
# 1/1 [==============================] - 0s 25ms/step
# LOOP #9392:
# Batch 9392 shape: (500, 4)
# Predicted 9392 shape: (1, 4)
# All predicted values shape: (9893, 4)
# 9393
# 1/1 [==============================] - 0s 31ms/step
# LOOP #9393:
# Batch 9393 shape: (500, 4)
# Predicted 9393 shape: (1, 4)
# All predicted values shape: (9894, 4)
# 9394
# 1/1 [==============================] - 0s 34ms/step
# LOOP #9394:
# Batch 9394 shape: (500, 4)
# Predicted 9394 shape: (1, 4)
# All predicted values shape: (9895, 4)
# 9395
# 1/1 [==============================] - 0s 37ms/step
# LOOP #9395:
# Batch 9395 shape: (500, 4)
# Predicted 9395 shape: (1, 4)
# All predicted values shape: (9896, 4)
# 9396
# 1/1 [==============================] - 0s 29ms/step
# LOOP #9396:
# Batch 9396 shape: (500, 4)
# Predicted 9396 shape: (1, 4)
# All predicted values shape: (9897, 4)
# 9397
# 1/1 [==============================] - 0s 27ms/step
# LOOP #9397:
# Batch 9397 shape: (500, 4)
# Predicted 9397 shape: (1, 4)
# All predicted values shape: (9898, 4)
# 9398
# 1/1 [==============================] - 0s 35ms/step
# LOOP #9398:
# Batch 9398 shape: (500, 4)
# Predicted 9398 shape: (1, 4)
# All predicted values shape: (9899, 4)
# 9399
# 1/1 [==============================] - 0s 31ms/step
# LOOP #9399:
# Batch 9399 shape: (500, 4)
# Predicted 9399 shape: (1, 4)
# All predicted values shape: (9900, 4)
# 9400
# 1/1 [==============================] - 0s 32ms/step
# LOOP #9400:
# Batch 9400 shape: (500, 4)
# Predicted 9400 shape: (1, 4)
# All predicted values shape: (9901, 4)
# 9401
# 1/1 [==============================] - 0s 33ms/step
# LOOP #9401:
# Batch 9401 shape: (500, 4)
# Predicted 9401 shape: (1, 4)
# All predicted values shape: (9902, 4)
# 9402
# 1/1 [==============================] - 0s 29ms/step
# LOOP #9402:
# Batch 9402 shape: (500, 4)
# Predicted 9402 shape: (1, 4)
# All predicted values shape: (9903, 4)
# 9403
# 1/1 [==============================] - 0s 31ms/step
# LOOP #9403:
# Batch 9403 shape: (500, 4)
# Predicted 9403 shape: (1, 4)
# All predicted values shape: (9904, 4)
# 9404
# 1/1 [==============================] - 0s 29ms/step
# LOOP #9404:
# Batch 9404 shape: (500, 4)
# Predicted 9404 shape: (1, 4)
# All predicted values shape: (9905, 4)
# 9405
# 1/1 [==============================] - 0s 32ms/step
# LOOP #9405:
# Batch 9405 shape: (500, 4)
# Predicted 9405 shape: (1, 4)
# All predicted values shape: (9906, 4)
# 9406
# 1/1 [==============================] - 0s 34ms/step
# LOOP #9406:
# Batch 9406 shape: (500, 4)
# Predicted 9406 shape: (1, 4)
# All predicted values shape: (9907, 4)
# 9407
# 1/1 [==============================] - 0s 32ms/step
# LOOP #9407:
# Batch 9407 shape: (500, 4)
# Predicted 9407 shape: (1, 4)
# All predicted values shape: (9908, 4)
# 9408
# 1/1 [==============================] - 0s 25ms/step
# LOOP #9408:
# Batch 9408 shape: (500, 4)
# Predicted 9408 shape: (1, 4)
# All predicted values shape: (9909, 4)
# 9409
# 1/1 [==============================] - 0s 31ms/step
# LOOP #9409:
# Batch 9409 shape: (500, 4)
# Predicted 9409 shape: (1, 4)
# All predicted values shape: (9910, 4)
# 9410
# 1/1 [==============================] - 0s 27ms/step
# LOOP #9410:
# Batch 9410 shape: (500, 4)
# Predicted 9410 shape: (1, 4)
# All predicted values shape: (9911, 4)
# 9411
# 1/1 [==============================] - 0s 29ms/step
# LOOP #9411:
# Batch 9411 shape: (500, 4)
# Predicted 9411 shape: (1, 4)
# All predicted values shape: (9912, 4)
# 9412
# 1/1 [==============================] - 0s 34ms/step
# LOOP #9412:
# Batch 9412 shape: (500, 4)
# Predicted 9412 shape: (1, 4)
# All predicted values shape: (9913, 4)
# 9413
# 1/1 [==============================] - 0s 28ms/step
# LOOP #9413:
# Batch 9413 shape: (500, 4)
# Predicted 9413 shape: (1, 4)
# All predicted values shape: (9914, 4)
# 9414
# 1/1 [==============================] - 0s 34ms/step
# LOOP #9414:
# Batch 9414 shape: (500, 4)
# Predicted 9414 shape: (1, 4)
# All predicted values shape: (9915, 4)
# 9415
# 1/1 [==============================] - 0s 33ms/step
# LOOP #9415:
# Batch 9415 shape: (500, 4)
# Predicted 9415 shape: (1, 4)
# All predicted values shape: (9916, 4)
# 9416
# 1/1 [==============================] - 0s 30ms/step
# LOOP #9416:
# Batch 9416 shape: (500, 4)
# Predicted 9416 shape: (1, 4)
# All predicted values shape: (9917, 4)
# 9417
# 1/1 [==============================] - 0s 36ms/step
# LOOP #9417:
# Batch 9417 shape: (500, 4)
# Predicted 9417 shape: (1, 4)
# All predicted values shape: (9918, 4)
# 9418
# 1/1 [==============================] - 0s 37ms/step
# LOOP #9418:
# Batch 9418 shape: (500, 4)
# Predicted 9418 shape: (1, 4)
# All predicted values shape: (9919, 4)
# 9419
# 1/1 [==============================] - 0s 32ms/step
# LOOP #9419:
# Batch 9419 shape: (500, 4)
# Predicted 9419 shape: (1, 4)
# All predicted values shape: (9920, 4)
# 9420
# 1/1 [==============================] - 0s 31ms/step
# LOOP #9420:
# Batch 9420 shape: (500, 4)
# Predicted 9420 shape: (1, 4)
# All predicted values shape: (9921, 4)
# 9421
# 1/1 [==============================] - 0s 32ms/step
# LOOP #9421:
# Batch 9421 shape: (500, 4)
# Predicted 9421 shape: (1, 4)
# All predicted values shape: (9922, 4)
# 9422
# 1/1 [==============================] - 0s 25ms/step
# LOOP #9422:
# Batch 9422 shape: (500, 4)
# Predicted 9422 shape: (1, 4)
# All predicted values shape: (9923, 4)
# 9423
# 1/1 [==============================] - 0s 26ms/step
# LOOP #9423:
# Batch 9423 shape: (500, 4)
# Predicted 9423 shape: (1, 4)
# All predicted values shape: (9924, 4)
# 9424
# 1/1 [==============================] - 0s 33ms/step
# LOOP #9424:
# Batch 9424 shape: (500, 4)
# Predicted 9424 shape: (1, 4)
# All predicted values shape: (9925, 4)
# 9425
# 1/1 [==============================] - 0s 28ms/step
# LOOP #9425:
# Batch 9425 shape: (500, 4)
# Predicted 9425 shape: (1, 4)
# All predicted values shape: (9926, 4)
# 9426
# 1/1 [==============================] - 0s 28ms/step
# LOOP #9426:
# Batch 9426 shape: (500, 4)
# Predicted 9426 shape: (1, 4)
# All predicted values shape: (9927, 4)
# 9427
# 1/1 [==============================] - 0s 28ms/step
# LOOP #9427:
# Batch 9427 shape: (500, 4)
# Predicted 9427 shape: (1, 4)
# All predicted values shape: (9928, 4)
# 9428
# 1/1 [==============================] - 0s 33ms/step
# LOOP #9428:
# Batch 9428 shape: (500, 4)
# Predicted 9428 shape: (1, 4)
# All predicted values shape: (9929, 4)
# 9429
# 1/1 [==============================] - 0s 46ms/step
# LOOP #9429:
# Batch 9429 shape: (500, 4)
# Predicted 9429 shape: (1, 4)
# All predicted values shape: (9930, 4)
# 9430
# 1/1 [==============================] - 0s 35ms/step
# LOOP #9430:
# Batch 9430 shape: (500, 4)
# Predicted 9430 shape: (1, 4)
# All predicted values shape: (9931, 4)
# 9431
# 1/1 [==============================] - 0s 31ms/step
# LOOP #9431:
# Batch 9431 shape: (500, 4)
# Predicted 9431 shape: (1, 4)
# All predicted values shape: (9932, 4)
# 9432
# 1/1 [==============================] - 0s 29ms/step
# LOOP #9432:
# Batch 9432 shape: (500, 4)
# Predicted 9432 shape: (1, 4)
# All predicted values shape: (9933, 4)
# 9433
# 1/1 [==============================] - 0s 35ms/step
# LOOP #9433:
# Batch 9433 shape: (500, 4)
# Predicted 9433 shape: (1, 4)
# All predicted values shape: (9934, 4)
# 9434
# 1/1 [==============================] - 0s 31ms/step
# LOOP #9434:
# Batch 9434 shape: (500, 4)
# Predicted 9434 shape: (1, 4)
# All predicted values shape: (9935, 4)
# 9435
# 1/1 [==============================] - 0s 34ms/step
# LOOP #9435:
# Batch 9435 shape: (500, 4)
# Predicted 9435 shape: (1, 4)
# All predicted values shape: (9936, 4)
# 9436
# 1/1 [==============================] - 0s 29ms/step
# LOOP #9436:
# Batch 9436 shape: (500, 4)
# Predicted 9436 shape: (1, 4)
# All predicted values shape: (9937, 4)
# 9437
# 1/1 [==============================] - 0s 29ms/step
# LOOP #9437:
# Batch 9437 shape: (500, 4)
# Predicted 9437 shape: (1, 4)
# All predicted values shape: (9938, 4)
# 9438
# 1/1 [==============================] - 0s 30ms/step
# LOOP #9438:
# Batch 9438 shape: (500, 4)
# Predicted 9438 shape: (1, 4)
# All predicted values shape: (9939, 4)
# 9439
# 1/1 [==============================] - 0s 42ms/step
# LOOP #9439:
# Batch 9439 shape: (500, 4)
# Predicted 9439 shape: (1, 4)
# All predicted values shape: (9940, 4)
# 9440
# 1/1 [==============================] - 0s 33ms/step
# LOOP #9440:
# Batch 9440 shape: (500, 4)
# Predicted 9440 shape: (1, 4)
# All predicted values shape: (9941, 4)
# 9441
# 1/1 [==============================] - 0s 25ms/step
# LOOP #9441:
# Batch 9441 shape: (500, 4)
# Predicted 9441 shape: (1, 4)
# All predicted values shape: (9942, 4)
# 9442
# 1/1 [==============================] - 0s 33ms/step
# LOOP #9442:
# Batch 9442 shape: (500, 4)
# Predicted 9442 shape: (1, 4)
# All predicted values shape: (9943, 4)
# 9443
# 1/1 [==============================] - 0s 27ms/step
# LOOP #9443:
# Batch 9443 shape: (500, 4)
# Predicted 9443 shape: (1, 4)
# All predicted values shape: (9944, 4)
# 9444
# 1/1 [==============================] - 0s 32ms/step
# LOOP #9444:
# Batch 9444 shape: (500, 4)
# Predicted 9444 shape: (1, 4)
# All predicted values shape: (9945, 4)
# 9445
# 1/1 [==============================] - 0s 36ms/step
# LOOP #9445:
# Batch 9445 shape: (500, 4)
# Predicted 9445 shape: (1, 4)
# All predicted values shape: (9946, 4)
# 9446
# 1/1 [==============================] - 0s 40ms/step
# LOOP #9446:
# Batch 9446 shape: (500, 4)
# Predicted 9446 shape: (1, 4)
# All predicted values shape: (9947, 4)
# 9447
# 1/1 [==============================] - 0s 33ms/step
# LOOP #9447:
# Batch 9447 shape: (500, 4)
# Predicted 9447 shape: (1, 4)
# All predicted values shape: (9948, 4)
# 9448
# 1/1 [==============================] - 0s 30ms/step
# LOOP #9448:
# Batch 9448 shape: (500, 4)
# Predicted 9448 shape: (1, 4)
# All predicted values shape: (9949, 4)
# 9449
# 1/1 [==============================] - 0s 34ms/step
# LOOP #9449:
# Batch 9449 shape: (500, 4)
# Predicted 9449 shape: (1, 4)
# All predicted values shape: (9950, 4)
# 9450
# 1/1 [==============================] - 0s 31ms/step
# LOOP #9450:
# Batch 9450 shape: (500, 4)
# Predicted 9450 shape: (1, 4)
# All predicted values shape: (9951, 4)
# 9451
# 1/1 [==============================] - 0s 34ms/step
# LOOP #9451:
# Batch 9451 shape: (500, 4)
# Predicted 9451 shape: (1, 4)
# All predicted values shape: (9952, 4)
# 9452
# 1/1 [==============================] - 0s 36ms/step
# LOOP #9452:
# Batch 9452 shape: (500, 4)
# Predicted 9452 shape: (1, 4)
# All predicted values shape: (9953, 4)
# 9453
# 1/1 [==============================] - 0s 26ms/step
# LOOP #9453:
# Batch 9453 shape: (500, 4)
# Predicted 9453 shape: (1, 4)
# All predicted values shape: (9954, 4)
# 9454
# 1/1 [==============================] - 0s 33ms/step
# LOOP #9454:
# Batch 9454 shape: (500, 4)
# Predicted 9454 shape: (1, 4)
# All predicted values shape: (9955, 4)
# 9455
# 1/1 [==============================] - 0s 29ms/step
# LOOP #9455:
# Batch 9455 shape: (500, 4)
# Predicted 9455 shape: (1, 4)
# All predicted values shape: (9956, 4)
# 9456
# 1/1 [==============================] - 0s 31ms/step
# LOOP #9456:
# Batch 9456 shape: (500, 4)
# Predicted 9456 shape: (1, 4)
# All predicted values shape: (9957, 4)
# 9457
# 1/1 [==============================] - 0s 28ms/step
# LOOP #9457:
# Batch 9457 shape: (500, 4)
# Predicted 9457 shape: (1, 4)
# All predicted values shape: (9958, 4)
# 9458
# 1/1 [==============================] - 0s 31ms/step
# LOOP #9458:
# Batch 9458 shape: (500, 4)
# Predicted 9458 shape: (1, 4)
# All predicted values shape: (9959, 4)
# 9459
# 1/1 [==============================] - 0s 39ms/step
# LOOP #9459:
# Batch 9459 shape: (500, 4)
# Predicted 9459 shape: (1, 4)
# All predicted values shape: (9960, 4)
# 9460
# 1/1 [==============================] - 0s 34ms/step
# LOOP #9460:
# Batch 9460 shape: (500, 4)
# Predicted 9460 shape: (1, 4)
# All predicted values shape: (9961, 4)
# 9461
# 1/1 [==============================] - 0s 30ms/step
# LOOP #9461:
# Batch 9461 shape: (500, 4)
# Predicted 9461 shape: (1, 4)
# All predicted values shape: (9962, 4)
# 9462
# 1/1 [==============================] - 0s 37ms/step
# LOOP #9462:
# Batch 9462 shape: (500, 4)
# Predicted 9462 shape: (1, 4)
# All predicted values shape: (9963, 4)
# 9463
# 1/1 [==============================] - 0s 26ms/step
# LOOP #9463:
# Batch 9463 shape: (500, 4)
# Predicted 9463 shape: (1, 4)
# All predicted values shape: (9964, 4)
# 9464
# 1/1 [==============================] - 0s 33ms/step
# LOOP #9464:
# Batch 9464 shape: (500, 4)
# Predicted 9464 shape: (1, 4)
# All predicted values shape: (9965, 4)
# 9465
# 1/1 [==============================] - 0s 33ms/step
# LOOP #9465:
# Batch 9465 shape: (500, 4)
# Predicted 9465 shape: (1, 4)
# All predicted values shape: (9966, 4)
# 9466
# 1/1 [==============================] - 0s 27ms/step
# LOOP #9466:
# Batch 9466 shape: (500, 4)
# Predicted 9466 shape: (1, 4)
# All predicted values shape: (9967, 4)
# 9467
# 1/1 [==============================] - 0s 32ms/step
# LOOP #9467:
# Batch 9467 shape: (500, 4)
# Predicted 9467 shape: (1, 4)
# All predicted values shape: (9968, 4)
# 9468
# 1/1 [==============================] - 0s 28ms/step
# LOOP #9468:
# Batch 9468 shape: (500, 4)
# Predicted 9468 shape: (1, 4)
# All predicted values shape: (9969, 4)
# 9469
# 1/1 [==============================] - 0s 37ms/step
# LOOP #9469:
# Batch 9469 shape: (500, 4)
# Predicted 9469 shape: (1, 4)
# All predicted values shape: (9970, 4)
# 9470
# 1/1 [==============================] - 0s 27ms/step
# LOOP #9470:
# Batch 9470 shape: (500, 4)
# Predicted 9470 shape: (1, 4)
# All predicted values shape: (9971, 4)
# 9471
# 1/1 [==============================] - 0s 29ms/step
# LOOP #9471:
# Batch 9471 shape: (500, 4)
# Predicted 9471 shape: (1, 4)
# All predicted values shape: (9972, 4)
# 9472
# 1/1 [==============================] - 0s 35ms/step
# LOOP #9472:
# Batch 9472 shape: (500, 4)
# Predicted 9472 shape: (1, 4)
# All predicted values shape: (9973, 4)
# 9473
# 1/1 [==============================] - 0s 26ms/step
# LOOP #9473:
# Batch 9473 shape: (500, 4)
# Predicted 9473 shape: (1, 4)
# All predicted values shape: (9974, 4)
# 9474
# 1/1 [==============================] - 0s 31ms/step
# LOOP #9474:
# Batch 9474 shape: (500, 4)
# Predicted 9474 shape: (1, 4)
# All predicted values shape: (9975, 4)
# 9475
# 1/1 [==============================] - 0s 36ms/step
# LOOP #9475:
# Batch 9475 shape: (500, 4)
# Predicted 9475 shape: (1, 4)
# All predicted values shape: (9976, 4)
# 9476
# 1/1 [==============================] - 0s 34ms/step
# LOOP #9476:
# Batch 9476 shape: (500, 4)
# Predicted 9476 shape: (1, 4)
# All predicted values shape: (9977, 4)
# 9477
# 1/1 [==============================] - 0s 31ms/step
# LOOP #9477:
# Batch 9477 shape: (500, 4)
# Predicted 9477 shape: (1, 4)
# All predicted values shape: (9978, 4)

# %%
#Plotting the results -Test set-

# Predicting with the model for HR - test set - ANN


# print("\nFor testing set:\n")

# predictions = ann_model_hr.predict(data_test_features)

# predictions = predictions.reshape(data_test_features.shape[0], data_test_features.shape[1]) # current shape is (length, numOfPrevValues, 1)
# predictions = predictions[:, 0] # getting values for the next time step (t) and not (t+1, t+2, or t+3)
# predictions = np.reshape(predictions, newshape=(len(predictions), 1))
# predictions[predictions > 1.0] = 1.0

get_and_print_rmse_for_model(data_test_label, all_values)
get_and_print_R2_for_model(data_test_label, all_values)
get_and_print_mae_for_model(data_test_label, all_values)
get_and_print_mape_for_model(data_test_label, all_values)

plot_actual_and_predictions_line(np.arange(0, len(data_test_label)), data_test_label, all_values)
# plot_actual_and_predictions_scatter(np.arange(0, len(data_test_label)), data_test_label, all_values)

# # this function won't plot properly if there are more than 3 variables in the model
# plot_model_data3D(data_test_features[:, :, 0][:, 0].flatten(), data_test_features[:, :, 2][:, 0].flatten(), data_test_features[:, :, 1][:, 0].flatten(),
#                  predictions.flatten(), "R-Wave Voltages", "SpO2", "HR") 

# column 1 for HR values, 0 for ECG R-Wave Voltages
print("\nAfter reversing the scaling: \n")

# For if MinMaxScaler was used; change the column number/index to get the values for other health variables
predictions_reversed = ((all_values - 0.1) / (1 - 0.1)) * (case4_filteredData_max[3] - case4_filteredData_max[3]) + case4_filteredData_max[3]
data_test_label_reversed = ((data_test_label - 0.1) / (1 - 0.1)) * (case4_filteredData_max[3] - case4_filteredData_max[3]) + case4_filteredData_max[3]
# data_test_features_reversed = ((data_test_features - 0.1) / (1 - 0.1)) * (combinedData_max[0] - combinedData_min[0]) + combinedData_min[0]
# predictions_reversed[predictions_reversed > 100] = 100

# For if standard scaling was used; change the column number/index to get the values for other health variables
# predictions_reversed = predictions * combinedData_stdDev[1] + combinedData_mean[1]
# data_test_label_reversed = data_test_label * combinedData_stdDev[1] + combinedData_mean[1]
# data_test_features_reversed = data_test_features * combinedData_stdDev[0] + combinedData_mean[0]

get_and_print_rmse_for_model(data_test_label_reversed, predictions_reversed)
get_and_print_R2_for_model(data_test_label_reversed, predictions_reversed)
get_and_print_mae_for_model(data_test_label_reversed, predictions_reversed)
get_and_print_mape_for_model(data_test_label_reversed, predictions_reversed)
# Out:
# RMSE:  0.15798414520424767
# R2 (Sklearn): -2.977803492269568
# MAE: 0.1184003145917554
# MAPE: 0.21018940641024036
# After reversing the scaling:
#
# RMSE:  0.0
# R2 (Sklearn): 1.0
# MAE: 0.0
# MAPE: 0.0
# 0.0

# %% [markdown]
# #New Plotting Results

# %%
#Plotting results

#HR
fig = plt.figure(figsize=(12, 8))
xtrain_set = np.arange(0, len(data_train_features))
ytrain_set = np.array(data_train_label[:,0])
plt.plot(xtrain_set, ytrain_set, 'b', label="Actual Train")

xtest_set = np.arange(len(data_train_features),len(data_train_features) + len(data_test_features))
ytest_set = np.array(data_test_label[:,0])
plt.plot(xtest_set, ytest_set, 'r', label="Actual Test")

pred_train_sig = np.array(predictions[:,0])
plt.plot(xtrain_set, pred_train_sig, 'orange', label="Predicted Train", linestyle="dotted")

pred_test_sig = np.array(all_values[:,0])
plt.plot(xtest_set, pred_test_sig,'green', label="Predicted Test", linestyle="dotted")
plt.title("Heart Rate (HR)")
plt.legend()
plt.show()



#SpO2
fig = plt.figure(figsize=(12, 8))
xtrain_set = np.arange(0, len(data_train_features))
ytrain_set = np.array(data_train_label[:,1])
plt.plot(xtrain_set, ytrain_set, 'b', label="Actual Train")

xtest_set = np.arange(len(data_train_features),len(data_train_features) + len(data_test_features))
ytest_set = np.array(data_test_label[:,1])
plt.plot(xtest_set, ytest_set, 'r', label="Actual Test")

pred_train_sig = np.array(predictions[:,1])
plt.plot(xtrain_set, pred_train_sig, 'orange', label="Predicted Train", linestyle="dotted")

pred_test_sig = np.array(all_values[:,1])
plt.plot(xtest_set, pred_test_sig,'green', label="Predicted Test", linestyle="dotted")
plt.title("SpO2")
plt.legend()
plt.show()





#NBP
fig = plt.figure(figsize=(12, 8))
xtrain_set = np.arange(0, len(data_train_features))
ytrain_set = np.array(data_train_label[:,2])
plt.plot(xtrain_set, ytrain_set, 'b', label="Actual Train")

xtest_set = np.arange(len(data_train_features),len(data_train_features) + len(data_test_features))
ytest_set = np.array(data_test_label[:,2])
plt.plot(xtest_set, ytest_set, 'r', label="Actual Test")

pred_train_sig = np.array(predictions[:,2])
plt.plot(xtrain_set, pred_train_sig, 'orange', label="Predicted Train", linestyle="dotted")

pred_test_sig = np.array(all_values[:,2])
plt.plot(xtest_set, pred_test_sig,'green', label="Predicted Test", linestyle="dotted")
plt.title("NBP")
plt.legend()
plt.show()





#ECG
fig = plt.figure(figsize=(12, 8))
xtrain_set = np.arange(0, len(data_train_features))
ytrain_set = np.array(data_train_label[:,3])
plt.plot(xtrain_set, ytrain_set, 'b', label="Actual Train")

xtest_set = np.arange(len(data_train_features),len(data_train_features) + len(data_test_features))
ytest_set = np.array(data_test_label[:,3])
plt.plot(xtest_set, ytest_set, 'r', label="Actual Test")

pred_train_sig = np.array(predictions[:,3])
plt.plot(xtrain_set, pred_train_sig, 'orange', label="Predicted Train", linestyle="dotted")

pred_test_sig = np.array(all_values[:,3])
plt.plot(xtest_set, pred_test_sig,'green', label="Predicted Test", linestyle="dotted")
plt.title("ECG")
plt.legend()
plt.show()
